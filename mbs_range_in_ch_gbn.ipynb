# %%
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#mbsgs9
#mbsgs10
#mbsgstc9
#mbsgstc10

loginId = 'mbsgs9'

loginPayload = {
    'loginId':loginId,
    'loginPw':'mbslive45@',
    'channel':'on'
}

'''
headers = {
    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'ko-KR,ko;q=0.8,en-US;q=0.6,en;q=0.4',
    'Cache-Control':'max-age=0',
    'Connection':'keep-alive',
    'Content-Length':'46',
    'Content-Type':'application/x-www-form-urlencoded',
    'Host':'125.144.163.12:8080',
    'Origin':'https://125.144.163.12:8080',
    'Referer':'https://125.144.163.12:8080/login.do',
    'Upgrade-Insecure-Requests':'1',
    'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'
}
'''
# Out:
# "\nheaders = {\n    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',\n    'Accept-Encoding':'gzip, deflate, br',\n    'Accept-Language':'ko-KR,ko;q=0.8,en-US;q=0.6,en;q=0.4',\n    'Cache-Control':'max-age=0',\n    'Connection':'keep-alive',\n    'Content-Length':'46',\n    'Content-Type':'application/x-www-form-urlencoded',\n    'Host':'125.144.163.12:8080',\n    'Origin':'https://125.144.163.12:8080',\n    'Referer':'https://125.144.163.12:8080/login.do',\n    'Upgrade-Insecure-Requests':'1',\n    'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'\n}\n"

# %%
s = requests.Session()
r = s.post('https://mbs.kt.com:8080/doLogin.do', data=loginPayload, verify=False, allow_redirects=False)
# Out:
# /home/jason/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py:838: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/security.html
#   InsecureRequestWarning)

# %%
r = s.post('https://mbs.kt.com:8080/home/homeMain.do', verify=False, allow_redirects=False)
# Out:
# /home/jason/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py:838: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/security.html
#   InsecureRequestWarning)

# %%
print(r.text)
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="ko" lang="ko">
# <head>
# 	<meta http-equiv="content-type" content="text/html; charset=utf-8"/>
#
#
#
#
#
#
# <link rel="stylesheet" href="/resources/css/normalize.css?ver=20170125">
# <link rel="stylesheet" href="/resources/css/style.css?ver=20170217">
# <link rel="stylesheet" href="/resources/css/jquery.loading-indicator.css?ver=20170125">
# <!--[if lte IE 9]><link rel="stylesheet" href="/resources/css/ie9.css"><![endif]-->
# <script src="/resources/bower/jquery/jquery.min.js?ver=20170125"></script>
# <script src="/resources/bower/jquery/jquery-migrate.min.js?ver=20170125"></script>
# <script src="/resources/bower/jquery-ui/ui/minified/jquery-ui.custom.min.js?ver=20170125"></script>
# <script src="/resources/js/front.js?ver=20170125"></script>
# <script src="/resources/js/common.js?ver=20170125"></script>
# <script src="/resources/js/jquery.loading-indicator.js?ver=20170125"></script>
# <script src="/resources/js/ch.color.map.js?ver=20170125"></script>
# <script src="/resources/js/jquery.fileDownload.js?ver=20170125"></script>
# <script src="/resources/js/jquery.cookie.js"></script>
# <!--[if lt IE 9]>
# <script src="/resources/bower/ie9-js/lib/IE9.js"></script>
# <script src="/resources/bower/respond/dest/respond.min.js"></script>
# <script src="/resources/bower/html5shiv/dist/html5shiv.min.js"></script>
# <![endif]-->
# 	<title>MBS</title>
#
# <script src="/resources/js/jquery.bxslider.min.js"></script>
# <!--[if lt IE 9]>
# <script src="/resources/bower/ie9-js/lib/IE9.js"></script>
# <script src="/resources/bower/respond/dest/respond.min.js"></script>
# <script src="/resources/bower/html5shiv/dist/html5shiv.min.js"></script>
# <![endif]-->
#
# 	<script type="text/javascript">
#
# 	</script>
# </head>
#
# <body>
# <div class="wrapper">
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# $(document).ready(function(){
# 	realtimeClock();
# 	openNoticePopup();
# });
#
# function doLogout(){
# 	if(confirm("로그아웃 하시겠습니까?")){
# 		location.href = "/doLogout.do";
# 	}
# }
#
# function goLogin(){
# 	location.href="/login.do";
# }
#
# function goChangePw(){
# 	location.href="/changePw.do";
# }
#
# function realtimeClock() {
# 	  //document.rtcForm.rtcInput.value = getTimeStamp();
# 	  $("#serverTime").html(getTimeStamp());
# 	  setTimeout("realtimeClock()", 1000);
# 	}
#
#
# 	function getTimeStamp() { // 24시간제
# 	  //var d = new Date();
# 	  var d = COMMON.fnStringTodate("20170420213314");
#
# 	  var s =
# 	    leadingZeros(d.getFullYear(), 4) + '-' +
# 	    leadingZeros(d.getMonth() + 1, 2) + '-' +
# 	    leadingZeros(d.getDate(), 2) + ' ' +
#
# 	    leadingZeros(d.getHours(), 2) + ':' +
# 	    leadingZeros(d.getMinutes(), 2);
# 	    // + ':' + leadingZeros(d.getSeconds(), 2);
#
# 	  return s;
# 	}
#
#
# 	function leadingZeros(n, digits) {
# 	  var zero = '';
# 	  n = n.toString();
#
# 	  if (n.length < digits) {
# 	    for (i = 0; i < digits - n.length; i++)
# 	      zero += '0';
# 	  }
# 	  return zero + n;
# 	}
#
# 	// 공지사항 팝업 오픈
# 	function openNoticePopup(){
# 		$("#popNotice").load("/notice/noticePopup.do", null, function(){
#
# 		});
# 	}
# </script>
# <!-- 레이어팝업 | 공지사항 -->
# <div class="layer_popup" id="popNotice">
# </div>
# <!-- // .layer_popup -->
# 	<div id="header">
# 		<div class="top">
# 			<div class="inside_wrap">
# 				<div class="system_name clear">
# 					<h1><img src="/resources/img/common/logo_mbs.png" alt="MBS"></h1>
# 					<p><img src="/resources/img/common/txt_header2.png" alt="Media Big-Data System">
# 				</div>
# 				<div class="login_info clear">
#
#
# 					<div class="login_before">
# 						<div class="manager_info clear">
# 							<p>
# 								<strong>Today</strong>
# 								<span class="date" id="serverTime"></span>
# 							</p>
# 							<p class="welcome_message">로그인 해주세요.</p>
# 						</div>
# 						<div class="btn_login">
# 							<button type="button" class="btn btn_dblue" onclick="goLogin()">로그인</button>
# 						</div>
# 					</div>
#
# 				</div>
# 			</div>
# 		</div>
# 		<!-- !.top -->
#
# 		<div class="gnb">
# 			<div class="inside_wrap">
# 				<ul class="gnb_main">
# 					<li class="act">
# 						<a href="/home/homeMain.do">HOME</a>
# 					</li>
# 					<li >
# 						<a href="/dashboard/dashboardMain.do">Dashboard</a>
# 					</li>
# 					<li >
# 						<a href="/realtime/prgmMain.do">실시간 시청행태</a>
# 						<ul class="gnb_sub">
# 							<li>
# 								<a href="/realtime/prgmMain.do">프로그램별</a>
# 							</li>
# 							<li>
# 								<a href="/realtime/regnMain.do">지역별</a>
# 							</li>
# 							<li>
# 								<a href="/realtime/chCompareMain.do" class="wsp_02">채널 비교</a>
# 							</li>
# 						</ul>
# 					</li>
# 					<li >
# 						<a href="/timely/channel/hourlyMain.do">유형별 시청행태</a>
# 						<ul class="gnb_sub">
# 							<li>
# 								<a href="/timely/channel/hourlyMain.do">채널</a>
# 							</li>
# 							<li>
# 								<a href="/timely/prgm/prgmMain.do">프로그램별</a>
# 							</li>
# 							<li>
# 								<a href="/timely/regn/regnMain.do">지역별</a>
# 							</li>
# 							<!--
# 							<li>
# 								<a href="/timely/compare/compareMain.do" class="wsp_02">채널 비교</a>
# 							</li>
# 							 -->
# 						</ul>
# 					</li>
# 					<li >
# 						<a href="/notice/noticeMain.do">공지사항</a>
# 					</li>
# 				</ul>
# 			</div>
# 		</div>
# 		<!-- !.gnb -->
#
# 	</div>
# 	<!-- !#header -->
#
#
#
#
#
#
#
#
# 	<div id="container" class="home_container">
# 		<div class="home_top">
# 			<div class="uhd_home">
# 				<div class="home_top_inside">
# 					<h2><img src="/resources/img/img_corp.png" alt="KT&KT skylife"></h2>
# 				</div>
# 			</div>
# 		</div>
# 		<div class="home_body">
# 			<div id="rolling">
# 				<ul class="slidee">
# 					<li class="rolling1">
# 						<h3><img src="/resources/img/h_home001.png" alt="지금 어디서 누가 얼마나 보고 있지? 실시간으로 판단한다"></h3>
# 						<div class="body_cont">
# 							<div class="mbs_home">
# 								<div class="text is-blind">
# 								    <h4>
# 								    	Media Big data Service
# 								    </h4>
# 								    <p>
# 								    	700만 가입자, 국내 최대 1등 커버리지
# 								    	<br>매년 약 90만 가입자 순증
# 								    </p>
# 								    <div class="world-first">
# 									    <h5>세계최초</h5>
# 									    <ul>
# 									    	<li>초단위 시청가구수 분석</li>
# 									    	<li>시청가구 이동 분석</li>
# 									    	<li>충성고객 분석 (지속시청&amp;반복시청가구 분석)</li>
# 									    	<li>타 채널과 비교분석</li>
# 									    </ul>
# 								    </div>
# 								    <div class="korea-rank1">
# 									    <h5>국내1등</h5>
# 									    <ul>
# 									    	<li>700만 가구</li>
# 									    	<li>100개 Live채널</li>
# 									    	<li>가입자의 전국 고른 분포</li>
# 									    	<li>IPTV와 위성 복합 분석</li>
# 									    	<li>최고의 노하우</li>
# 									    </ul>
# 								    </div>
# 							    </div>
# 							    <img src="/resources/img/img_home_body_001.png" alt="">
# 							</div>
# 						</div>
# 					</li>
# 					<li class="rolling2">
# 						<h3><img src="/resources/img/h_home002.png" alt="1등 신뢰도 초단위 시청가구수 전수 조사"></h3>
# 						<div class="body_cont clear">
# 							<div class="mbs_home mbs_home_l">
# 								<img src="/resources/img/img_home_body_002l.png" alt="">
# 							</div>
# 							<div class="mbs_home mbs_home_r">
# 								<div class="text is-blind">
# 									<h4>
# 								    	다양한분석
# 								    </h4>
# 								    <ul>
# 								    	<li>채널분석</li>
# 								    	<li>프로그램 분석</li>
# 								    	<li>요일별 분석</li>
# 								    	<li>경쟁 분석</li>
# 								    	<li>충성도 분석</li>
# 								    </ul>
# 								    <p>
# 								    	채널/시간별 시청가구 수 그래프 제공
# 								    </p>
# 								    <h4>
# 								    	원하는 채널/프로그램/시간대의 지역별 분석
# 								    </h4>
# 								    <ul>
# 								    	<li>원하는 채널</li>
# 								    	<li>원하는 시간</li>
# 								    	<li>원하는 프로그램</li>
# 								    	<li>원하는 지역별</li>
# 								    </ul>
# 								    <div class="korea-rank1">
# 									    <h5>국내1등</h5>
# 									    <ul>
# 									    	<li>700만 가구</li>
# 									    	<li>100개 Live채널</li>
# 									    	<li>가입자의 전국 고른 분포</li>
# 									    	<li>IPTV와 위성 복합 분석</li>
# 									    	<li>최고의 노하우</li>
# 									    </ul>
# 								    </div>
# 								</div>
# 								<img src="/resources/img/img_home_body_002r.png" alt="">
# 							</div>
# 						</div>
# 					</li>
# 				</ul>
# 			</div>
# 		</div>
# 	</div>
# 	<!-- !#container -->
#
# <script>
# var rollingHome = {
# 	flickDish : null,
# 	flickOpt  : {
# 		mode : 'horizontal',
# 		speed: 1000,
#   		pause: 4500,
# 		//easing : 'ease-out',
# 		auto: true,
# 		autoControls : false,
# 		controls : true,
# 		autoHover:true
#
# 	},
# 	flickApp : function(id){
# 		var _self = this;
# 		var options = self.flickOpt;
# 		_self.flickDish = $(id).bxSlider(options);
# 	},
# 	init : function(){
# 		var _self = this;
# 		_self.flickApp('#rolling .slidee');
#
# 	}
# };
# (function(){
# 	rollingHome.init();
# })();
# </script>
#
#
#
#
#
#
#
# 	<div id="footer">
# 		<div class="inside_wrap clear">
# 			<div class="company_info kt_company_info">
# 				<h6><a href=""><img src="/resources/img/common/logo_gray_kt.png" alt="KT"></a></h6>
# 				<p class="copyright">
# 					(주)케이티 대표이사 황창규 / 사업자등록번호102-81-42945 <span class="divider">/</span> 케이티 통신판매업신고2002-경기성남-0048
# 					<br>13606 경기도 성남시 분당구 불정로 90 (정자동 206번지) / TEL국번없이 100 (무료)
# 					<br>Copyright &copy; 2011 - 2016 kt corp. All rights reserved.
# 				</p>
# 			</div>
# 			<div class="company_info skylife_company_info">
# 				<h6><a href=""><img src="/resources/img/common/logo_gray_sl.png" alt="skylife"></a></h6>
# 				<p class="copyright">
# 					대표이사 이남기 / 사업자등록번호 117-81-31120 <span class="divider">/</span> 통신판매업 신고번호 2013-서울마포-1528
# 					<br>서울특별시 마포구 매봉산로 75 DDMC 빌딩 8,9층
# 					<br>Copyright &copy; 2013 by KT Skylife Co., Ltd. All Rights Reserved.
# 				</p>
# 			</div>
# 		</div>
# 	</div>
# 	<!-- !#footer -->
# </div>
#
# <!-- 레이어팝업 | 알럿팝업 -->
# <div class="layer_popup" id="alertPopup">
# 	<div class="layer_bg"></div>
# 	<div class="popup">
# 		<div class="pop_basic">
# 			<div class="pop_content">
# 				<div class="request_ment">
# 					<p id="alertPopupTxt">
# 					</p>
# 				</div>
# 				<div class="action">
# 					<a href="#popCouonInqBtn" onclick="closePop('#alertPopup');" class="btn btn_blue pop_cls">확인</a>
# 				</div>
# 			</div>
# 			<!-- // .pop_content -->
# 		</div>
# 		<!-- // .pop_basic -->
#
# 	</div>
# 	<!-- // .popup -->
#
# </div>
# <!-- // .layer_popup -->
#
# </body>
# </html>

# %%
print(s.cookies)
# Out:
# <RequestsCookieJar[<Cookie JSESSIONID=304C3D3CDB317612A874F7703FBCB4D2 for mbs.kt.com/>, <Cookie ui="{b:...,s:QdOLIDESdRUHLiCa6y4XMVmxd5VGHVElSwJQm4kn/z6WJ6mAFuy7rC/VH6zp5d6YRj6ksCPl1wZ7rGfZ9d7QEcvi4WwwN3u/WrafEpYdPe6M1TwxBMoEe9W9Re9asTnseTTtwqmWGDx4ig0YvDxjUBUz8wlos0dKVmvINRZ6eOw=}" for mbs.kt.com/>]>

# %%
#uiCookie = r.request.headers['Cookie'] + ';loginId=' + loginId
#uiCookie
jar = requests.cookies.RequestsCookieJar()
jar.set('loginId', loginId)
jar.set('ui', r.request.headers['Cookie'])
#cookie = {'loginId':loginId}
#cookie
# Out:
# Cookie(version=0, name='ui', value='ui="{b:...,s:QdOLIDESdRUHLiCa6y4XMVmxd5VGHVElSwJQm4kn/z6WJ6mAFuy7rC/VH6zp5d6YRj6ksCPl1wZ7rGfZ9d7QEcvi4WwwN3u/WrafEpYdPe6M1TwxBMoEe9W9Re9asTnseTTtwqmWGDx4ig0YvDxjUBUz8wlos0dKVmvINRZ6eOw=}"; JSESSIONID=6C9B104656BC4521DF9C3CC6D55D7B28', port=None, port_specified=False, domain='', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False)

# %%
payload = {'lastTime':'20170420203400', 'chGbnCd':'C001','screenType':'T'}

r = s.get('https://125.144.163.12:8080/chart/rangeInChGbn.do', params=payload, cookies = jar, headers = {
        'Connection': 'keep-alive',
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36',
        'X-Requested-With':'XMLHttpRequest'
}, verify=False)
# Out:
# /home/jason/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py:838: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/security.html
#   InsecureRequestWarning)

# %%
# cookie
print(s.cookies)
# Out:
# <RequestsCookieJar[<Cookie JSESSIONID=304C3D3CDB317612A874F7703FBCB4D2 for mbs.kt.com/>, <Cookie ui="{b:...,s:QdOLIDESdRUHLiCa6y4XMVmxd5VGHVElSwJQm4kn/z6WJ6mAFuy7rC/VH6zp5d6YRj6ksCPl1wZ7rGfZ9d7QEcvi4WwwN3u/WrafEpYdPe6M1TwxBMoEe9W9Re9asTnseTTtwqmWGDx4ig0YvDxjUBUz8wlos0dKVmvINRZ6eOw=}" for mbs.kt.com/>]>

# %%
print(r.url)
# Out:
# https://125.144.163.12:8080/chart/rangeInChGbn.do?screenType=T&chGbnCd=C001&lastTime=20170420203400

# %%
print(r.request.headers)
# Out:
# {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'X-Requested-With': 'XMLHttpRequest', 'Cookie': 'ui=ui="{b:...,s:QdOLIDESdRUHLiCa6y4XMVmxd5VGHVElSwJQm4kn/z6WJ6mAFuy7rC/VH6zp5d6YRj6ksCPl1wZ7rGfZ9d7QEcvi4WwwN3u/WrafEpYdPe6M1TwxBMoEe9W9Re9asTnseTTtwqmWGDx4ig0YvDxjUBUz8wlos0dKVmvINRZ6eOw=}"; JSESSIONID=6C9B104656BC4521DF9C3CC6D55D7B28; loginId=mbsgs9', 'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36', 'Connection': 'keep-alive'}

# %%
r.headers
# Out:
# {'Content-Security-Policy': "script-src 'self' 'unsafe-inline' 'unsafe-eval'", 'Pragma': 'no-cache', 'Keep-Alive': 'timeout=5, max=100', 'Server': 'Apache/2.4.23 (Unix) OpenSSL/1.0.1k-fips mod_jk/1.2.42', 'X-Content-Type-Options': 'nosniff', 'Date': 'Thu, 20 Apr 2017 12:34:38 GMT', 'X-Frame-Options': 'SAMEORIGIN', 'X-XSS-Protection': '1; mode=block', 'Expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'Content-Disposition': 'inline;filename=f.txt', 'Connection': 'Keep-Alive', 'Cache-Control': 'no-cache,no-store,must-revalidate', 'Transfer-Encoding': 'chunked', 'Content-Type': 'application/json;charset=UTF-8'}

# %%
r.text
# Out:
# '{"result":"0000","msg":"","chNo":null,"otsChNo":"S14","otvChNo":"8","lastTime":"20170420213330","prevChList":[{"time":"20170420203410","viewCntOTS":0,"viewCntOTV":0,"list":[{"prgm_id":"P841026195","prev_ch_no":"5","prev_ch_nm":"SBS","prev_disp_ch_nm":"SBS","ch_color":"#26c1ee","prev_prgm_id":"C840053025","view_cnt":4},{"prgm_id":"P841026195","prev_ch_no":"7","prev_ch_nm":"KBS2","prev_disp_ch_nm":"KBS2","ch_color":"#9164c3","prev_prgm_id":"P840932997","view_cnt":16},{"prgm_id":"P841026195","prev_ch_no":"9","prev_ch_nm":"KBS1","prev_disp_ch_nm":"KBS1","ch_color":"#4a67d3","prev_prgm_id":"C840078641","view_cnt":5},{"prgm_id":"R019999063","prev_ch_no":"S11","prev_ch_nm":"MBC","prev_disp_ch_nm":"MBC","ch_color":"#cd3d3d","prev_prgm_id":"R019966961","view_cnt":17}]},{"time":"20170420203420","viewCntOTS":0,"viewCntOTV":0,"list":[{"prgm_id":"P841026195","prev_ch_no":"5","prev_ch_nm":"SBS","prev_disp_ch_nm":"SBS","ch_color":"#26c1ee","prev_prgm_id":"C840053025","view_cnt":9},{"prgm_id":"P841026195","prev_ch_no":"7","prev_ch_nm":"KBS2","prev_disp_ch_nm":"KBS2","ch_color":"#9164c3","prev_prgm_id":"P840932997","view_cnt":19},{"prgm_id":"P841026195","prev_ch_no":"9","prev_ch_nm":"KBS1","prev_disp_ch_nm":"KBS1","ch_color":"#4a67d3","prev_prgm_id":"C840078641","view_cnt":9},{"prgm_id":"R019999063","prev_ch_no":"S11","prev_ch_nm":"MBC","prev_disp_ch_nm":"MBC","ch_color":"#cd3d3d","prev_prgm_id":"R019966961","view_cnt":17}]},{"time":"20170420203430","viewCntOTS":0,"viewCntOTV":0,"list":[{"prgm_id":"P841026195","prev_ch_no":"5","prev_ch_nm":"SBS","prev_disp_ch_nm":"SBS","ch_color":"#26c1ee","prev_prgm_id":"C840053025","view_cnt":1},{"prgm_id":"P841026195","prev_ch_no":"7","prev_ch_nm":"KBS2","prev_disp_ch_nm":"KBS2","ch_color":"#9164c3","prev_prgm_id":"P840932997","view_cnt":4},{"prgm_id":"P841026195","prev_ch_no":"9","prev_ch_nm":"KBS1","prev_disp_ch_nm":"KBS1","ch_color":"#4a67d3","prev_prgm_id":"C840078641","view_cnt":7},{"prgm_id":"P841026195","prev_ch_no":"11","prev_ch_nm":"MBC","prev_disp_ch_nm":"MBC","ch_color":"#cd3d3d","prev_prgm_id":"C840120559","view_cnt":2}]},{"time":"20170420203440","viewCntOTS":0,"viewCntOTV":0,"list":[{"prgm_id":"P841026195","prev_ch_no":"5","prev_ch_nm":"SBS","prev_disp_ch_nm":"SBS","ch_color":"#26c1ee","prev_prgm_id":"C840053025","view_cnt":9},{"prgm_id":"P841026195","prev_ch_no":"7","prev_ch_nm":"KBS2","prev_disp_ch_nm":"KBS2","ch_color":"#9164c3","prev_prgm_id":"P840932997","view_cnt":11},{"prgm_id":"P841026195","prev_ch_no":"9","prev_ch_nm":"KBS1","prev_disp_ch_nm":"KBS1","ch_color":"#4a67d3","prev_prgm_id":"C840078641","view_cnt":6},{"prgm_id":"R019999063","prev_ch_no":"S11","prev_ch_nm":"MBC","prev_disp_ch_nm":"MBC","ch_color":"#cd3d3d","prev_prgm_id":"R019966961","view_cnt":9}]},{"time":"20170420203450","viewCntOTS":0,"viewCntOTV":0,"list":[{"prgm_id":"P841026195","prev_ch_no":"5","prev_ch_nm":"SBS","prev_disp_ch_nm":"SBS","ch_color":"#26c1ee","prev_prgm_id":"C840053025","view_cnt":6},{"prgm_id":"P841026195","prev_ch_no":"7","prev_ch_nm":"KBS2","prev_disp_ch_nm":"KBS2","ch_color":"#9164c3","prev_prgm_id":"P840932997","view_cnt":28},{"prgm_id":"P841026195","prev_ch_no":"9","prev_ch_nm":"KBS1","prev_disp_ch_nm":"KBS1","ch_color":"#4a67d3","prev_prgm_id":"C840078641","view_cnt":11},{"prgm_id":"R019999063","prev_ch_no":"S11","prev_ch_nm":"MBC","prev_disp_ch_nm":"MBC","ch_color":"#cd3d3d","prev_prgm_id":"R019966961","view_cnt":5}]},{"time":"20170420203500","viewCntOTS":0,"viewCntOTV":0,"list":[{"prgm_id":"P841026195","prev_ch_no":"5","prev_ch_nm":"SBS","prev_disp_ch_nm":"SBS","ch_color":"#26c1ee","prev_prgm_id":"C840053025","view_cnt":14},{"prgm_id":"P841026195","prev_ch_no":"7","prev_ch_nm":"KBS2","prev_disp_ch_nm":"KBS2","ch_color":"#9164c3","prev_prgm_id":"P840932997","view_cnt":31},{"prgm_id":"P841026195","prev_ch_no":"9","prev_ch_nm":"KBS1","prev_disp_ch_nm":"KBS1","ch_color":"#4a67d3","prev_prgm_id":"C840078641","view_cnt":3},{"prgm_id":"R019999063","prev_ch_no":"S11","prev_ch_nm":"MBC","prev_disp_ch_nm ...

# %%
data = json.loads(r.text)

# %%
len(data['prevChList'])
# Out:
# 357

# %%
temp = []
for item in data['prevChList']:
    row = []    
    for temprow in item['list']:
        listitem = {}
        listitem['time'] = item['time']
        listitem['prgm_id'] = temprow['prgm_id']
        listitem['ch_color'] = temprow['ch_color']
        listitem['prev_ch_no'] = temprow['prev_ch_no']
        listitem['prev_ch_nm'] = temprow['prev_ch_nm']
        listitem['prev_disp_ch_nm'] = temprow['prev_disp_ch_nm']
        listitem['prev_prgm_id'] = temprow['prev_prgm_id']
        listitem['view_cnt'] = temprow['view_cnt']
        print(listitem)
        #row.append(listitem)
        temp.append(listitem)

temp
# Out:
# {'prev_disp_ch_nm': 'SBS', 'prev_ch_nm': 'SBS', 'view_cnt': 4, 'prgm_id': 'P841026195', 'time': '20170420203410', 'prev_ch_no': '5', 'prev_prgm_id': 'C840053025', 'ch_color': '#26c1ee'}
# {'prev_disp_ch_nm': 'KBS2', 'prev_ch_nm': 'KBS2', 'view_cnt': 16, 'prgm_id': 'P841026195', 'time': '20170420203410', 'prev_ch_no': '7', 'prev_prgm_id': 'P840932997', 'ch_color': '#9164c3'}
# {'prev_disp_ch_nm': 'KBS1', 'prev_ch_nm': 'KBS1', 'view_cnt': 5, 'prgm_id': 'P841026195', 'time': '20170420203410', 'prev_ch_no': '9', 'prev_prgm_id': 'C840078641', 'ch_color': '#4a67d3'}
# {'prev_disp_ch_nm': 'MBC', 'prev_ch_nm': 'MBC', 'view_cnt': 17, 'prgm_id': 'R019999063', 'time': '20170420203410', 'prev_ch_no': 'S11', 'prev_prgm_id': 'R019966961', 'ch_color': '#cd3d3d'}
# {'prev_disp_ch_nm': 'SBS', 'prev_ch_nm': 'SBS', 'view_cnt': 9, 'prgm_id': 'P841026195', 'time': '20170420203420', 'prev_ch_no': '5', 'prev_prgm_id': 'C840053025', 'ch_color': '#26c1ee'}
# {'prev_disp_ch_nm': 'KBS2', 'prev_ch_nm': 'KBS2', 'view_cnt': 19, 'prgm_id': 'P841026195', 'time': '20170420203420', 'prev_ch_no': '7', 'prev_prgm_id': 'P840932997', 'ch_color': '#9164c3'}
# {'prev_disp_ch_nm': 'KBS1', 'prev_ch_nm': 'KBS1', 'view_cnt': 9, 'prgm_id': 'P841026195', 'time': '20170420203420', 'prev_ch_no': '9', 'prev_prgm_id': 'C840078641', 'ch_color': '#4a67d3'}
# {'prev_disp_ch_nm': 'MBC', 'prev_ch_nm': 'MBC', 'view_cnt': 17, 'prgm_id': 'R019999063', 'time': '20170420203420', 'prev_ch_no': 'S11', 'prev_prgm_id': 'R019966961', 'ch_color': '#cd3d3d'}
# {'prev_disp_ch_nm': 'SBS', 'prev_ch_nm': 'SBS', 'view_cnt': 1, 'prgm_id': 'P841026195', 'time': '20170420203430', 'prev_ch_no': '5', 'prev_prgm_id': 'C840053025', 'ch_color': '#26c1ee'}
# {'prev_disp_ch_nm': 'KBS2', 'prev_ch_nm': 'KBS2', 'view_cnt':
# {'prev_disp_ch_nm': 'KBS2', 'prev_ch_nm': 'KBS2', 'view_cnt': 82, 'prgm_id': 'P841026179', 'time': '20170420204440', 'prev_ch_no': '7', 'prev_prgm_id': 'P840932997', 'ch_color': '#9164c3'}
# {'prev_disp_ch_nm': 'KBS1', 'prev_ch_nm': 'KBS1', 'view_cnt': 21, 'prgm_id': 'P841026179', 'time': '20170420204440', 'prev_ch_no': '9', 'prev_prgm_id': 'C840078641', 'ch_color': '#4a67d3'}
# ...
#   'time': '20170420211230',
#   'view_cnt': 15},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211230',
#   'view_cnt': 36},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211230',
#   'view_cnt': 14},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026179',
#   'time': '20170420211240',
#   'view_cnt': 9},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211240',
#   'view_cnt': 23},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211240',
#   'view_cnt': 31},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211240',
#   'view_cnt': 10},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211250',
#   'view_cnt': 14},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211250',
#   'view_cnt': 18},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211250',
#   'view_cnt': 49},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211250',
#   'view_cnt': 11},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211300',
#   'view_cnt': 12},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211300',
#   'view_cnt': 19},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211300',
#   'view_cnt': 66},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211300',
#   'view_cnt': 8},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211310',
#   'view_cnt': 10},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211310',
#   'view_cnt': 22},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211310',
#   'view_cnt': 39},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211310',
#   'view_cnt': 13},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211320',
#   'view_cnt': 8},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211320',
#   'view_cnt': 35},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211320',
#   'view_cnt': 36},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211320',
#   'view_cnt': 9},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211330',
#   'view_cnt': 10},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211330',
#   'view_cnt': 26},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211330',
#   'view_cnt': 27},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211330',
#   'view_cnt': 13},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211340',
#   'view_cnt': 8},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932998',
#   'prgm_id': 'P841026179',
#   'time': '20170420211340',
#   'view_cnt': 29},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211340',
#   'view_cnt': 22},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211340',
#   'view_cnt': 12},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211350',
#   'view_cnt': 4},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211350',
#   'view_cnt': 27},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211350',
#   'view_cnt': 23},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211350',
#   'view_cnt': 8},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211400',
#   'view_cnt': 9},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211400',
#   'view_cnt': 55},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211400',
#   'view_cnt': 14},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211400',
#   'view_cnt': 9},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211410',
#   'view_cnt': 12},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211410',
#   'view_cnt': 88},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211410',
#   'view_cnt': 8},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211410',
#   'view_cnt': 13},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211420',
#   'view_cnt': 11},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211420',
#   'view_cnt': 63},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211420',
#   'view_cnt': 12},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211420',
#   'view_cnt': 6},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211430',
#   'view_cnt': 10},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211430',
#   'view_cnt': 41},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211430',
#   'view_cnt': 9},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': 'S11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'R019966958',
#   'prgm_id': 'R019999064',
#   'time': '20170420211430',
#   'view_cnt': 3},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211440',
#   'view_cnt': 4},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211440',
#   'view_cnt': 44},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211440',
#   'view_cnt': 16},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211440',
#   'view_cnt': 4},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211450',
#   'view_cnt': 15},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211450',
#   'view_cnt': 56},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211450',
#   'view_cnt': 7},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211450',
#   'view_cnt': 3},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211500',
#   'view_cnt': 9},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211500',
#   'view_cnt': 71},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211500',
#   'view_cnt': 30},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211500',
#   'view_cnt': 12},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211510',
#   'view_cnt': 16},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211510',
#   'view_cnt': 65},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211510',
#   'view_cnt': 27},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211510',
#   'view_cnt': 5},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211520',
#   'view_cnt': 17},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211520',
#   'view_cnt': 69},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211520',
#   'view_cnt': 38},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211520',
#   'view_cnt': 6},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211530',
#   'view_cnt': 21},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211530',
#   'view_cnt': 59},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211530',
#   'view_cnt': 46},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211530',
#   'view_cnt': 11},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053024',
#   'prgm_id': 'P841026179',
#   'time': '20170420211540',
#   'view_cnt': 22},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211540',
#   'view_cnt': 58},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211540',
#   'view_cnt': 26},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211540',
#   'view_cnt': 8},
#  ...]

# %%
temp
# Out:
# [{'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203410',
#   'view_cnt': 4},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203410',
#   'view_cnt': 16},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203410',
#   'view_cnt': 5},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': 'S11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'R019966961',
#   'prgm_id': 'R019999063',
#   'time': '20170420203410',
#   'view_cnt': 17},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203420',
#   'view_cnt': 9},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203420',
#   'view_cnt': 19},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203420',
#   'view_cnt': 9},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': 'S11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'R019966961',
#   'prgm_id': 'R019999063',
#   'time': '20170420203420',
#   'view_cnt': 17},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203430',
#   'view_cnt': 1},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203430',
#   'view_cnt': 4},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203430',
#   'view_cnt': 7},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203430',
#   'view_cnt': 2},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203440',
#   'view_cnt': 9},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203440',
#   'view_cnt': 11},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203440',
#   'view_cnt': 6},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': 'S11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'R019966961',
#   'prgm_id': 'R019999063',
#   'time': '20170420203440',
#   'view_cnt': 9},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203450',
#   'view_cnt': 6},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203450',
#   'view_cnt': 28},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203450',
#   'view_cnt': 11},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': 'S11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'R019966961',
#   'prgm_id': 'R019999063',
#   'time': '20170420203450',
#   'view_cnt': 5},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203500',
#   'view_cnt': 14},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203500',
#   'view_cnt': 31},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203500',
#   'view_cnt': 3},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': 'S11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'R019966961',
#   'prgm_id': 'R019999063',
#   'time': '20170420203500',
#   'view_cnt': 8},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203510',
#   'view_cnt': 11},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203510',
#   'view_cnt': 38},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203510',
#   'view_cnt': 9},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203510',
#   'view_cnt': 10},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203520',
#   'view_cnt': 10},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203520',
#   'view_cnt': 45},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203520',
#   'view_cnt': 6},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': 'S11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'R019966961',
#   'prgm_id': 'R019999063',
#   'time': '20170420203520',
#   'view_cnt': 2},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203530',
#   'view_cnt': 15},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203530',
#   'view_cnt': 57},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203530',
#   'view_cnt': 4},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203530',
#   'view_cnt': 5},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203540',
#   'view_cnt': 19},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203540',
#   'view_cnt': 133},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203540',
#   'view_cnt': 7},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203540',
#   'view_cnt': 9},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203550',
#   'view_cnt': 10},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203550',
#   'view_cnt': 166},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': 'S9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'R019998046',
#   'prgm_id': 'R019999063',
#   'time': '20170420203550',
#   'view_cnt': 7},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203550',
#   'view_cnt': 2},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203600',
#   'view_cnt': 14},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203600',
#   'view_cnt': 60},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203600',
#   'view_cnt': 5},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203600',
#   'view_cnt': 5},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203610',
#   'view_cnt': 11},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203610',
#   'view_cnt': 39},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203610',
#   'view_cnt': 11},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203610',
#   'view_cnt': 12},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203620',
#   'view_cnt': 7},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203620',
#   'view_cnt': 37},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203620',
#   'view_cnt': 5},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203620',
#   'view_cnt': 6},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203630',
#   'view_cnt': 13},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203630',
#   'view_cnt': 32},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203630',
#   'view_cnt': 6},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203630',
#   'view_cnt': 8},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203640',
#   'view_cnt': 27},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203640',
#   'view_cnt': 39},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203640',
#   'view_cnt': 11},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203640',
#   'view_cnt': 10},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203650',
#   'view_cnt': 24},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203650',
#   'view_cnt': 44},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203650',
#   'view_cnt': 3},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203650',
#   'view_cnt': 9},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203700',
#   'view_cnt': 29},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203700',
#   'view_cnt': 38},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203700',
#   'view_cnt': 14},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203700',
#   'view_cnt': 10},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203710',
#   'view_cnt': 50},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203710',
#   'view_cnt': 48},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203710',
#   'view_cnt': 10},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203710',
#   'view_cnt': 9},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203720',
#   'view_cnt': 34},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203720',
#   'view_cnt': 33},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203720',
#   'view_cnt': 9},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203720',
#   'view_cnt': 8},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203730',
#   'view_cnt': 24},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203730',
#   'view_cnt': 37},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203730',
#   'view_cnt': 10},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203730',
#   'view_cnt': 6},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203740',
#   'view_cnt': 27},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203740',
#   'view_cnt': 50},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203740',
#   'view_cnt': 14},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203740',
#   'view_cnt': 4},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203750',
#   'view_cnt': 12},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203750',
#   'view_cnt': 30},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203750',
#   'view_cnt': 14},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'P841000791',
#   'prgm_id': 'P841026195',
#   'time': '20170420203750',
#   'view_cnt': 9},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203800',
#   'view_cnt': 9},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203800',
#   'view_cnt': 31},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203800',
#   'view_cnt': 14},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203800',
#   'view_cnt': 7},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203810',
#   'view_cnt': 11},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203810',
#   'view_cnt': 23},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203810',
#   'view_cnt': 9},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203810',
#   'view_cnt': 5},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203820',
#   'view_cnt': 19},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203820',
#   'view_cnt': 19},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203820',
#   'view_cnt': 10},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': 'S11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'R019966961',
#   'prgm_id': 'R019999063',
#   'time': '20170420203820',
#   'view_cnt': 1},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203830',
#   'view_cnt': 17},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203830',
#   'view_cnt': 21},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203830',
#   'view_cnt': 12},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203830',
#   'view_cnt': 6},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203840',
#   'view_cnt': 23},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203840',
#   'view_cnt': 34},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203840',
#   'view_cnt': 25},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203840',
#   'view_cnt': 6},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203850',
#   'view_cnt': 13},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203850',
#   'view_cnt': 27},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203850',
#   'view_cnt': 26},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203850',
#   'view_cnt': 14},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203900',
#   'view_cnt': 20},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203900',
#   'view_cnt': 41},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203900',
#   'view_cnt': 29},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203900',
#   'view_cnt': 14},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203910',
#   'view_cnt': 21},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203910',
#   'view_cnt': 35},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': 'S9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'R019998046',
#   'prgm_id': 'R019999063',
#   'time': '20170420203910',
#   'view_cnt': 58},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': 'S11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'R019966961',
#   'prgm_id': 'R019999063',
#   'time': '20170420203910',
#   'view_cnt': 8},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203920',
#   'view_cnt': 6},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203920',
#   'view_cnt': 13},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203920',
#   'view_cnt': 29},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203920',
#   'view_cnt': 14},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203930',
#   'view_cnt': 7},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203930',
#   'view_cnt': 19},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203930',
#   'view_cnt': 18},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203930',
#   'view_cnt': 7},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203940',
#   'view_cnt': 10},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203940',
#   'view_cnt': 16},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': 'S9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'R019998046',
#   'prgm_id': 'R019999063',
#   'time': '20170420203940',
#   'view_cnt': 21},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203940',
#   'view_cnt': 8},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420203950',
#   'view_cnt': 10},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420203950',
#   'view_cnt': 25},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420203950',
#   'view_cnt': 25},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420203950',
#   'view_cnt': 13},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053025',
#   'prgm_id': 'P841026195',
#   'time': '20170420204000',
#   'view_cnt': 15},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026195',
#   'time': '20170420204000',
#   'view_cnt': 26},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026195',
#   'time': '20170420204000',
#   'view_cnt': 25},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026195',
#   'time': '20170420204000',
#   'view_cnt': 17},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': 'S5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'R019936644',
#   'prgm_id': 'R019999064',
#   'time': '20170420204010',
#   'view_cnt': 15},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026179',
#   'time': '20170420204010',
#   'view_cnt': 30},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026179',
#   'time': '20170420204010',
#   'view_cnt': 27},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026179',
#   'time': '20170420204010',
#   'view_cnt': 9},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': 'S5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'R019936644',
#   'prgm_id': 'R019999064',
#   'time': '20170420204020',
#   'view_cnt': 10},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026179',
#   'time': '20170420204020',
#   'view_cnt': 27},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026179',
#   'time': '20170420204020',
#   'view_cnt': 21},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026179',
#   'time': '20170420204020',
#   'view_cnt': 23},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': 'S5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'R019936644',
#   'prgm_id': 'R019999064',
#   'time': '20170420204030',
#   'view_cnt': 11},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026179',
#   'time': '20170420204030',
#   'view_cnt': 30},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078641',
#   'prgm_id': 'P841026179',
#   'time': '20170420204030',
#   'view_cnt': 17},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120559',
#   'prgm_id': 'P841026179',
#   'time': '20170420204030',
#   'view_cnt': 11},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': 'S5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'R019936644',
#   'prgm_id': 'R019999064',
#   'time': '20170420204040',
#   'view_cnt': 19},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': '7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'P840932997',
#   'prgm_id': 'P841026179',
#   'time': '20170420

#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211400',
#   'view_cnt': 9},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211400',
#   'view_cnt': 55},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211400',
#   'view_cnt': 14},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211400',
#   'view_cnt': 9},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211410',
#   'view_cnt': 12},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211410',
#   'view_cnt': 88},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211410',
#   'view_cnt': 8},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211410',
#   'view_cnt': 13},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211420',
#   'view_cnt': 11},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211420',
#   'view_cnt': 63},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211420',
#   'view_cnt': 12},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211420',
#   'view_cnt': 6},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211430',
#   'view_cnt': 10},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211430',
#   'view_cnt': 41},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211430',
#   'view_cnt': 9},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': 'S11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'R019966958',
#   'prgm_id': 'R019999064',
#   'time': '20170420211430',
#   'view_cnt': 3},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211440',
#   'view_cnt': 4},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211440',
#   'view_cnt': 44},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211440',
#   'view_cnt': 16},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211440',
#   'view_cnt': 4},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211450',
#   'view_cnt': 15},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211450',
#   'view_cnt': 56},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211450',
#   'view_cnt': 7},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211450',
#   'view_cnt': 3},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211500',
#   'view_cnt': 9},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211500',
#   'view_cnt': 71},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211500',
#   'view_cnt': 30},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211500',
#   'view_cnt': 12},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211510',
#   'view_cnt': 16},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211510',
#   'view_cnt': 65},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211510',
#   'view_cnt': 27},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211510',
#   'view_cnt': 5},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211520',
#   'view_cnt': 17},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211520',
#   'view_cnt': 69},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211520',
#   'view_cnt': 38},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211520',
#   'view_cnt': 6},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053026',
#   'prgm_id': 'P841026179',
#   'time': '20170420211530',
#   'view_cnt': 21},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211530',
#   'view_cnt': 59},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211530',
#   'view_cnt': 46},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211530',
#   'view_cnt': 11},
#  {'ch_color': '#26c1ee',
#   'prev_ch_nm': 'SBS',
#   'prev_ch_no': '5',
#   'prev_disp_ch_nm': 'SBS',
#   'prev_prgm_id': 'C840053024',
#   'prgm_id': 'P841026179',
#   'time': '20170420211540',
#   'view_cnt': 22},
#  {'ch_color': '#9164c3',
#   'prev_ch_nm': 'KBS2',
#   'prev_ch_no': 'S7',
#   'prev_disp_ch_nm': 'KBS2',
#   'prev_prgm_id': 'R019996308',
#   'prgm_id': 'R019999064',
#   'time': '20170420211540',
#   'view_cnt': 58},
#  {'ch_color': '#4a67d3',
#   'prev_ch_nm': 'KBS1',
#   'prev_ch_no': '9',
#   'prev_disp_ch_nm': 'KBS1',
#   'prev_prgm_id': 'C840078642',
#   'prgm_id': 'P841026179',
#   'time': '20170420211540',
#   'view_cnt': 26},
#  {'ch_color': '#cd3d3d',
#   'prev_ch_nm': 'MBC',
#   'prev_ch_no': '11',
#   'prev_disp_ch_nm': 'MBC',
#   'prev_prgm_id': 'C840120560',
#   'prgm_id': 'P841026179',
#   'time': '20170420211540',
#   'view_cnt': 8},
#  ...]

# %%
df_mbs = pd.DataFrame(temp)
df_mbs
# Out:
#      ch_color prev_ch_nm prev_ch_no prev_disp_ch_nm prev_prgm_id     prgm_id  \
# 0     #26c1ee        SBS          5             SBS   C840053025  P841026195
# 1     #9164c3       KBS2          7            KBS2   P840932997  P841026195
# 2     #4a67d3       KBS1          9            KBS1   C840078641  P841026195
# 3     #cd3d3d        MBC        S11             MBC   R019966961  R019999063
# 4     #26c1ee        SBS          5             SBS   C840053025  P841026195
# 5     #9164c3       KBS2          7            KBS2   P840932997  P841026195
# 6     #4a67d3       KBS1          9            KBS1   C840078641  P841026195
# 7     #cd3d3d        MBC        S11             MBC   R019966961  R019999063
# 8     #26c1ee        SBS          5             SBS   C840053025  P841026195
# 9     #9164c3       KBS2          7            KBS2   P840932997  P841026195
# 10    #4a67d3       KBS1          9            KBS1   C840078641  P841026195
# 11    #cd3d3d        MBC         11             MBC   C840120559  P841026195
# 12    #26c1ee        SBS          5             SBS   C840053025  P841026195
# 13    #9164c3       KBS2          7            KBS2   P840932997  P841026195
# 14    #4a67d3       KBS1          9            KBS1   C840078641  P841026195
# 15    #cd3d3d        MBC        S11             MBC   R019966961  R019999063
# 16    #26c1ee        SBS          5             SBS   C840053025  P841026195
# 17    #9164c3       KBS2          7            KBS2   P840932997  P841026195
# 18    #4a67d3       KBS1          9            KBS1   C840078641  P841026195
# 19    #cd3d3d        MBC        S11             MBC   R019966961  R019999063
# 20    #26c1ee        SBS          5             SBS   C840053025  P841026195
# 21    #9164c3       KBS2          7            KBS2   P840932997  P841026195
# 22    #4a67d3       KBS1          9            KBS1   C840078641  P841026195
# 23    #cd3d3d        MBC        S11             MBC   R019966961  R019999063
# 24    #26c1ee        SBS          5             SBS   C840053025  P841026195
# 25    #9164c3       KBS2          7            KBS2   P840932997  P841026195
# 26    #4a67d3       KBS1          9            KBS1   C840078641  P841026195
# 27    #cd3d3d        MBC         11             MBC   C840120559  P841026195
# 28    #26c1ee        SBS          5             SBS   C840053025  P841026195
# 29    #9164c3       KBS2          7            KBS2   P840932997  P841026195
# ...       ...        ...        ...             ...          ...         ...
# 1398  #4a67d3       KBS1          9            KBS1   C840078642  P841026179
# 1399  #cd3d3d        MBC        S11             MBC   R019966963  R019999064
# 1400  #26c1ee        SBS          5             SBS   C840053026  P841026179
# 1401  #9164c3       KBS2         S7            KBS2   R019996308  R019999064
# 1402  #4a67d3       KBS1          9            KBS1   C840078642  P841026179
# 1403  #cd3d3d        MBC        S11             MBC   R019966963  R019999064
# 1404  #26c1ee        SBS          5             SBS   C840053026  P841026179
# 1405  #9164c3       KBS2         S7            KBS2   R019996308  R019999064
# 1406  #4a67d3       KBS1          9            KBS1   C840078642  P841026179
# 1407  #cd3d3d        MBC        S11             MBC   R019966963  R019999064
# 1408  #26c1ee        SBS          5             SBS   C840053026  P841026179
# 1409  #9164c3       KBS2         S7            KBS2   R019996308  R019999064
# 1410  #4a67d3       KBS1          9            KBS1   C840078642  P841026179
# 1411  #cd3d3d        MBC        S11             MBC   R019966963  R019999064
# 1412  #26c1ee        SBS          5             SBS   C840053026  P841026179
# 1413  #9164c3       KBS2         S7            KBS2   R019996308  R019999064
# 1414  #4a67d3       KBS1          9            KBS1   C840078642  P841026179
# 1415  #cd3d3d        MBC        S11             MBC   R019966963  R019999064
# 1416  #26c1ee        SBS          5             SBS   C840053026  P841026179
# 1417  #9164c3       KBS2         S7            KBS2   R019996308  R019999064
# 1418  #4a67d3       KBS1          9            KBS1   C840078642  P841026179
# 1419  #cd3d3d        MBC        S11             MBC   R019966963  R019999064
# 1420  #26c1ee        SBS          5             SBS   C840053026  P841026179
# 1421  #9164c3       KBS2          7            KBS2   P840932998  P841026179
# 1422  #4a67d3       KBS1          9            KBS1   C840078642  P841026179
# 1423  #cd3d3d        MBC        S11             MBC   R019966963  R019999064
# 1424  #26c1ee        SBS          5             SBS   C840053026  P841026179
# 1425  #9164c3       KBS2          7            KBS2   P840932998  P841026179
# 1426  #4a67d3       KBS1          9            KBS1   C840078642  P841026179
# 1427  #cd3d3d        MBC        S11             MBC   R019966963  R019999064
#
#                 time  view_cnt
# 0     20170420203410         4
# 1     20170420203410        16
# 2     20170420203410         5
# 3     20170420203410        17
# 4     20170420203420         9
# 5     20170420203420        19
# 6     20170420203420         9
# 7     20170420203420        17
# 8     20170420203430         1
# 9     20170420203430         4
# 10    20170420203430         7
# 11    20170420203430         2
# 12    20170420203440         9
# 13    20170420203440        11
# 14    20170420203440         6
# 15    20170420203440         9
# 16    20170420203450         6
# 17    20170420203450        28
# 18    20170420203450        11
# 19    20170420203450         5
# 20    20170420203500        14
# 21    20170420203500        31
# 22    20170420203500         3
# 23    20170420203500         8
# 24    20170420203510        11
# 25    20170420203510        38
# 26    20170420203510         9
# 27    20170420203510        10
# 28    20170420203520        10
# 29    20170420203520        45
# ...              ...       ...
# 1398  20170420213220        26
# 1399  20170420213220        14
# 1400  20170420213230         8
# 1401  20170420213230        47
# 1402  20170420213230        32
# 1403  20170420213230         6
# 1404  20170420213240         9
# 1405  20170420213240        29
# 1406  20170420213240        29
# 1407  20170420213240         8
# 1408  20170420213250         7
# 1409  20170420213250        25
# 1410  20170420213250        18
# 1411  20170420213250         7
# 1412  20170420213300         4
# 1413  20170420213300        13
# 1414  20170420213300        25
# 1415  20170420213300         4
# 1416  20170420213310         7
# 1417  20170420213310        27
# 1418  20170420213310        26
# 1419  20170420213310        11
# 1420  20170420213320         5
# 1421  20170420213320        23
# 1422  20170420213320        29
# 1423  20170420213320        18
# 1424  20170420213330         6
# 1425  20170420213330        29
# 1426  20170420213330        30
# 1427  20170420213330        16
#
# [1428 rows x 8 columns]

# %% [markdown]
# # CSV 출력하기

# %%
df_mbs.to_excel('kt_skylife_range_in_ch_gbn.xlsx', sheet_name='kt_skylife_range_in_ch_gbn')

# %%
df_mbs.to_csv('kt_skylife_range_in_ch_gbn.csv')
