# %%
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#mbsgs9
#mbsgs10
#mbsgstc9
#mbsgstc10

loginId = 'mbsgs9'

loginPayload = {
    'loginId':loginId,
    'loginPw':'mbslive45@',
    'channel':'on'
}

'''
headers = {
    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'ko-KR,ko;q=0.8,en-US;q=0.6,en;q=0.4',
    'Cache-Control':'max-age=0',
    'Connection':'keep-alive',
    'Content-Length':'46',
    'Content-Type':'application/x-www-form-urlencoded',
    'Host':'125.144.163.12:8080',
    'Origin':'https://125.144.163.12:8080',
    'Referer':'https://125.144.163.12:8080/login.do',
    'Upgrade-Insecure-Requests':'1',
    'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'
}
'''
# Out:
# "\nheaders = {\n    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',\n    'Accept-Encoding':'gzip, deflate, br',\n    'Accept-Language':'ko-KR,ko;q=0.8,en-US;q=0.6,en;q=0.4',\n    'Cache-Control':'max-age=0',\n    'Connection':'keep-alive',\n    'Content-Length':'46',\n    'Content-Type':'application/x-www-form-urlencoded',\n    'Host':'125.144.163.12:8080',\n    'Origin':'https://125.144.163.12:8080',\n    'Referer':'https://125.144.163.12:8080/login.do',\n    'Upgrade-Insecure-Requests':'1',\n    'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'\n}\n"

# %%
s = requests.Session()
r = s.post('https://mbs.kt.com:8080/doLogin.do', data=loginPayload, verify=False, allow_redirects=False)
# Out:
# /home/jason/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py:838: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/security.html
#   InsecureRequestWarning)

# %%
r = s.post('https://mbs.kt.com:8080/home/homeMain.do', verify=False, allow_redirects=False)
# Out:
# /home/jason/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py:838: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/security.html
#   InsecureRequestWarning)

# %%
print(r.text)
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="ko" lang="ko">
# <head>
# 	<meta http-equiv="content-type" content="text/html; charset=utf-8"/>
#
#
#
#
#
#
# <link rel="stylesheet" href="/resources/css/normalize.css?ver=20170125">
# <link rel="stylesheet" href="/resources/css/style.css?ver=20170217">
# <link rel="stylesheet" href="/resources/css/jquery.loading-indicator.css?ver=20170125">
# <!--[if lte IE 9]><link rel="stylesheet" href="/resources/css/ie9.css"><![endif]-->
# <script src="/resources/bower/jquery/jquery.min.js?ver=20170125"></script>
# <script src="/resources/bower/jquery/jquery-migrate.min.js?ver=20170125"></script>
# <script src="/resources/bower/jquery-ui/ui/minified/jquery-ui.custom.min.js?ver=20170125"></script>
# <script src="/resources/js/front.js?ver=20170125"></script>
# <script src="/resources/js/common.js?ver=20170125"></script>
# <script src="/resources/js/jquery.loading-indicator.js?ver=20170125"></script>
# <script src="/resources/js/ch.color.map.js?ver=20170125"></script>
# <script src="/resources/js/jquery.fileDownload.js?ver=20170125"></script>
# <script src="/resources/js/jquery.cookie.js"></script>
# <!--[if lt IE 9]>
# <script src="/resources/bower/ie9-js/lib/IE9.js"></script>
# <script src="/resources/bower/respond/dest/respond.min.js"></script>
# <script src="/resources/bower/html5shiv/dist/html5shiv.min.js"></script>
# <![endif]-->
# 	<title>MBS</title>
#
# <script src="/resources/js/jquery.bxslider.min.js"></script>
# <!--[if lt IE 9]>
# <script src="/resources/bower/ie9-js/lib/IE9.js"></script>
# <script src="/resources/bower/respond/dest/respond.min.js"></script>
# <script src="/resources/bower/html5shiv/dist/html5shiv.min.js"></script>
# <![endif]-->
#
# 	<script type="text/javascript">
#
# 	</script>
# </head>
#
# <body>
# <div class="wrapper">
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# $(document).ready(function(){
# 	realtimeClock();
# 	openNoticePopup();
# });
#
# function doLogout(){
# 	if(confirm("로그아웃 하시겠습니까?")){
# 		location.href = "/doLogout.do";
# 	}
# }
#
# function goLogin(){
# 	location.href="/login.do";
# }
#
# function goChangePw(){
# 	location.href="/changePw.do";
# }
#
# function realtimeClock() {
# 	  //document.rtcForm.rtcInput.value = getTimeStamp();
# 	  $("#serverTime").html(getTimeStamp());
# 	  setTimeout("realtimeClock()", 1000);
# 	}
#
#
# 	function getTimeStamp() { // 24시간제
# 	  //var d = new Date();
# 	  var d = COMMON.fnStringTodate("20170420210651");
#
# 	  var s =
# 	    leadingZeros(d.getFullYear(), 4) + '-' +
# 	    leadingZeros(d.getMonth() + 1, 2) + '-' +
# 	    leadingZeros(d.getDate(), 2) + ' ' +
#
# 	    leadingZeros(d.getHours(), 2) + ':' +
# 	    leadingZeros(d.getMinutes(), 2);
# 	    // + ':' + leadingZeros(d.getSeconds(), 2);
#
# 	  return s;
# 	}
#
#
# 	function leadingZeros(n, digits) {
# 	  var zero = '';
# 	  n = n.toString();
#
# 	  if (n.length < digits) {
# 	    for (i = 0; i < digits - n.length; i++)
# 	      zero += '0';
# 	  }
# 	  return zero + n;
# 	}
#
# 	// 공지사항 팝업 오픈
# 	function openNoticePopup(){
# 		$("#popNotice").load("/notice/noticePopup.do", null, function(){
#
# 		});
# 	}
# </script>
# <!-- 레이어팝업 | 공지사항 -->
# <div class="layer_popup" id="popNotice">
# </div>
# <!-- // .layer_popup -->
# 	<div id="header">
# 		<div class="top">
# 			<div class="inside_wrap">
# 				<div class="system_name clear">
# 					<h1><img src="/resources/img/common/logo_mbs.png" alt="MBS"></h1>
# 					<p><img src="/resources/img/common/txt_header2.png" alt="Media Big-Data System">
# 				</div>
# 				<div class="login_info clear">
#
#
# 					<div class="login_before">
# 						<div class="manager_info clear">
# 							<p>
# 								<strong>Today</strong>
# 								<span class="date" id="serverTime"></span>
# 							</p>
# 							<p class="welcome_message">로그인 해주세요.</p>
# 						</div>
# 						<div class="btn_login">
# 							<button type="button" class="btn btn_dblue" onclick="goLogin()">로그인</button>
# 						</div>
# 					</div>
#
# 				</div>
# 			</div>
# 		</div>
# 		<!-- !.top -->
#
# 		<div class="gnb">
# 			<div class="inside_wrap">
# 				<ul class="gnb_main">
# 					<li class="act">
# 						<a href="/home/homeMain.do">HOME</a>
# 					</li>
# 					<li >
# 						<a href="/dashboard/dashboardMain.do">Dashboard</a>
# 					</li>
# 					<li >
# 						<a href="/realtime/prgmMain.do">실시간 시청행태</a>
# 						<ul class="gnb_sub">
# 							<li>
# 								<a href="/realtime/prgmMain.do">프로그램별</a>
# 							</li>
# 							<li>
# 								<a href="/realtime/regnMain.do">지역별</a>
# 							</li>
# 							<li>
# 								<a href="/realtime/chCompareMain.do" class="wsp_02">채널 비교</a>
# 							</li>
# 						</ul>
# 					</li>
# 					<li >
# 						<a href="/timely/channel/hourlyMain.do">유형별 시청행태</a>
# 						<ul class="gnb_sub">
# 							<li>
# 								<a href="/timely/channel/hourlyMain.do">채널</a>
# 							</li>
# 							<li>
# 								<a href="/timely/prgm/prgmMain.do">프로그램별</a>
# 							</li>
# 							<li>
# 								<a href="/timely/regn/regnMain.do">지역별</a>
# 							</li>
# 							<!--
# 							<li>
# 								<a href="/timely/compare/compareMain.do" class="wsp_02">채널 비교</a>
# 							</li>
# 							 -->
# 						</ul>
# 					</li>
# 					<li >
# 						<a href="/notice/noticeMain.do">공지사항</a>
# 					</li>
# 				</ul>
# 			</div>
# 		</div>
# 		<!-- !.gnb -->
#
# 	</div>
# 	<!-- !#header -->
#
#
#
#
#
#
#
#
# 	<div id="container" class="home_container">
# 		<div class="home_top">
# 			<div class="uhd_home">
# 				<div class="home_top_inside">
# 					<h2><img src="/resources/img/img_corp.png" alt="KT&KT skylife"></h2>
# 				</div>
# 			</div>
# 		</div>
# 		<div class="home_body">
# 			<div id="rolling">
# 				<ul class="slidee">
# 					<li class="rolling1">
# 						<h3><img src="/resources/img/h_home001.png" alt="지금 어디서 누가 얼마나 보고 있지? 실시간으로 판단한다"></h3>
# 						<div class="body_cont">
# 							<div class="mbs_home">
# 								<div class="text is-blind">
# 								    <h4>
# 								    	Media Big data Service
# 								    </h4>
# 								    <p>
# 								    	700만 가입자, 국내 최대 1등 커버리지
# 								    	<br>매년 약 90만 가입자 순증
# 								    </p>
# 								    <div class="world-first">
# 									    <h5>세계최초</h5>
# 									    <ul>
# 									    	<li>초단위 시청가구수 분석</li>
# 									    	<li>시청가구 이동 분석</li>
# 									    	<li>충성고객 분석 (지속시청&amp;반복시청가구 분석)</li>
# 									    	<li>타 채널과 비교분석</li>
# 									    </ul>
# 								    </div>
# 								    <div class="korea-rank1">
# 									    <h5>국내1등</h5>
# 									    <ul>
# 									    	<li>700만 가구</li>
# 									    	<li>100개 Live채널</li>
# 									    	<li>가입자의 전국 고른 분포</li>
# 									    	<li>IPTV와 위성 복합 분석</li>
# 									    	<li>최고의 노하우</li>
# 									    </ul>
# 								    </div>
# 							    </div>
# 							    <img src="/resources/img/img_home_body_001.png" alt="">
# 							</div>
# 						</div>
# 					</li>
# 					<li class="rolling2">
# 						<h3><img src="/resources/img/h_home002.png" alt="1등 신뢰도 초단위 시청가구수 전수 조사"></h3>
# 						<div class="body_cont clear">
# 							<div class="mbs_home mbs_home_l">
# 								<img src="/resources/img/img_home_body_002l.png" alt="">
# 							</div>
# 							<div class="mbs_home mbs_home_r">
# 								<div class="text is-blind">
# 									<h4>
# 								    	다양한분석
# 								    </h4>
# 								    <ul>
# 								    	<li>채널분석</li>
# 								    	<li>프로그램 분석</li>
# 								    	<li>요일별 분석</li>
# 								    	<li>경쟁 분석</li>
# 								    	<li>충성도 분석</li>
# 								    </ul>
# 								    <p>
# 								    	채널/시간별 시청가구 수 그래프 제공
# 								    </p>
# 								    <h4>
# 								    	원하는 채널/프로그램/시간대의 지역별 분석
# 								    </h4>
# 								    <ul>
# 								    	<li>원하는 채널</li>
# 								    	<li>원하는 시간</li>
# 								    	<li>원하는 프로그램</li>
# 								    	<li>원하는 지역별</li>
# 								    </ul>
# 								    <div class="korea-rank1">
# 									    <h5>국내1등</h5>
# 									    <ul>
# 									    	<li>700만 가구</li>
# 									    	<li>100개 Live채널</li>
# 									    	<li>가입자의 전국 고른 분포</li>
# 									    	<li>IPTV와 위성 복합 분석</li>
# 									    	<li>최고의 노하우</li>
# 									    </ul>
# 								    </div>
# 								</div>
# 								<img src="/resources/img/img_home_body_002r.png" alt="">
# 							</div>
# 						</div>
# 					</li>
# 				</ul>
# 			</div>
# 		</div>
# 	</div>
# 	<!-- !#container -->
#
# <script>
# var rollingHome = {
# 	flickDish : null,
# 	flickOpt  : {
# 		mode : 'horizontal',
# 		speed: 1000,
#   		pause: 4500,
# 		//easing : 'ease-out',
# 		auto: true,
# 		autoControls : false,
# 		controls : true,
# 		autoHover:true
#
# 	},
# 	flickApp : function(id){
# 		var _self = this;
# 		var options = self.flickOpt;
# 		_self.flickDish = $(id).bxSlider(options);
# 	},
# 	init : function(){
# 		var _self = this;
# 		_self.flickApp('#rolling .slidee');
#
# 	}
# };
# (function(){
# 	rollingHome.init();
# })();
# </script>
#
#
#
#
#
#
#
# 	<div id="footer">
# 		<div class="inside_wrap clear">
# 			<div class="company_info kt_company_info">
# 				<h6><a href=""><img src="/resources/img/common/logo_gray_kt.png" alt="KT"></a></h6>
# 				<p class="copyright">
# 					(주)케이티 대표이사 황창규 / 사업자등록번호102-81-42945 <span class="divider">/</span> 케이티 통신판매업신고2002-경기성남-0048
# 					<br>13606 경기도 성남시 분당구 불정로 90 (정자동 206번지) / TEL국번없이 100 (무료)
# 					<br>Copyright &copy; 2011 - 2016 kt corp. All rights reserved.
# 				</p>
# 			</div>
# 			<div class="company_info skylife_company_info">
# 				<h6><a href=""><img src="/resources/img/common/logo_gray_sl.png" alt="skylife"></a></h6>
# 				<p class="copyright">
# 					대표이사 이남기 / 사업자등록번호 117-81-31120 <span class="divider">/</span> 통신판매업 신고번호 2013-서울마포-1528
# 					<br>서울특별시 마포구 매봉산로 75 DDMC 빌딩 8,9층
# 					<br>Copyright &copy; 2013 by KT Skylife Co., Ltd. All Rights Reserved.
# 				</p>
# 			</div>
# 		</div>
# 	</div>
# 	<!-- !#footer -->
# </div>
#
# <!-- 레이어팝업 | 알럿팝업 -->
# <div class="layer_popup" id="alertPopup">
# 	<div class="layer_bg"></div>
# 	<div class="popup">
# 		<div class="pop_basic">
# 			<div class="pop_content">
# 				<div class="request_ment">
# 					<p id="alertPopupTxt">
# 					</p>
# 				</div>
# 				<div class="action">
# 					<a href="#popCouonInqBtn" onclick="closePop('#alertPopup');" class="btn btn_blue pop_cls">확인</a>
# 				</div>
# 			</div>
# 			<!-- // .pop_content -->
# 		</div>
# 		<!-- // .pop_basic -->
#
# 	</div>
# 	<!-- // .popup -->
#
# </div>
# <!-- // .layer_popup -->
#
# </body>
# </html>

# %%
print(s.cookies)
# Out:
# <RequestsCookieJar[<Cookie JSESSIONID=86A601B7A44F0A117338752766B42390 for mbs.kt.com/>, <Cookie ui="{b:...,s:a3Iis0e32Y9b3KYorJaViH/OeANCfMD63d+k7SWdJmPNfHA4Qoea+5QQGkcgphmRYJeADpeMuBGcuXV0Td1tKdoYWTDxDonNRpbF4pvUfIIqmZcEJDBHBJLnsk+SKRafPpCGMh3jm1XOBad7qNl+OJcz3VhLhZPWDz/wf6GPVaI=}" for mbs.kt.com/>]>

# %%
#uiCookie = r.request.headers['Cookie'] + ';loginId=' + loginId
#uiCookie
jar = requests.cookies.RequestsCookieJar()
jar.set('loginId', loginId)
jar.set('ui', r.request.headers['Cookie'])
#cookie = {'loginId':loginId}
#cookie
# Out:
# Cookie(version=0, name='ui', value='ui="{b:...,s:a3Iis0e32Y9b3KYorJaViH/OeANCfMD63d+k7SWdJmPNfHA4Qoea+5QQGkcgphmRYJeADpeMuBGcuXV0Td1tKdoYWTDxDonNRpbF4pvUfIIqmZcEJDBHBJLnsk+SKRafPpCGMh3jm1XOBad7qNl+OJcz3VhLhZPWDz/wf6GPVaI=}"; JSESSIONID=F664FBF7CFE15588C84E49D9FB116AD1', port=None, port_specified=False, domain='', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False)

# %%
payload = {'lastTime':'20170420200800', 'screenType':'S'}

'''
r = s.get('https://125.144.163.12:8080/chart/rangeInterestCh.do', params=payload, headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, sdch, br', 
    'accept-language': 'en-US,en;q=0.8',
    'Cache-Control': 'max-age=0',
    'Host': '125.144.163.12:8080',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36',
    'X-Requested-With':'XMLHttpRequest',
    'Content-Type':'application/x-www-form-urlencoded',
    'Cookie': uiCookie
}, verify=False)
'''
r = s.get('https://125.144.163.12:8080/chart/rangeInterestCh.do', params=payload, cookies = jar, headers = {
        'Connection': 'keep-alive',
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36',
        'X-Requested-With':'XMLHttpRequest'
}, verify=False)
# Out:
# /home/jason/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py:838: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/security.html
#   InsecureRequestWarning)

# %%
# cookie
print(s.cookies)
# Out:
# <RequestsCookieJar[<Cookie JSESSIONID=86A601B7A44F0A117338752766B42390 for mbs.kt.com/>, <Cookie ui="{b:...,s:a3Iis0e32Y9b3KYorJaViH/OeANCfMD63d+k7SWdJmPNfHA4Qoea+5QQGkcgphmRYJeADpeMuBGcuXV0Td1tKdoYWTDxDonNRpbF4pvUfIIqmZcEJDBHBJLnsk+SKRafPpCGMh3jm1XOBad7qNl+OJcz3VhLhZPWDz/wf6GPVaI=}" for mbs.kt.com/>]>

# %%
print(r.url)
# Out:
# https://125.144.163.12:8080/chart/rangeInterestCh.do?lastTime=20170420200800&screenType=S

# %%
print(r.request.headers)
# Out:
# {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36', 'X-Requested-With': 'XMLHttpRequest', 'Cookie': 'ui=ui="{b:...,s:a3Iis0e32Y9b3KYorJaViH/OeANCfMD63d+k7SWdJmPNfHA4Qoea+5QQGkcgphmRYJeADpeMuBGcuXV0Td1tKdoYWTDxDonNRpbF4pvUfIIqmZcEJDBHBJLnsk+SKRafPpCGMh3jm1XOBad7qNl+OJcz3VhLhZPWDz/wf6GPVaI=}"; JSESSIONID=F664FBF7CFE15588C84E49D9FB116AD1; loginId=mbsgs9', 'Accept': '*/*', 'Connection': 'keep-alive', 'Accept-Encoding': 'gzip, deflate'}

# %%
r.headers
# Out:
# {'Keep-Alive': 'timeout=5, max=100', 'X-Content-Type-Options': 'nosniff', 'Transfer-Encoding': 'chunked', 'X-Frame-Options': 'SAMEORIGIN', 'Server': 'Apache/2.4.23 (Unix) OpenSSL/1.0.1k-fips mod_jk/1.2.42', 'Expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'X-XSS-Protection': '1; mode=block', 'Date': 'Thu, 20 Apr 2017 12:08:33 GMT', 'Content-Type': 'application/json;charset=UTF-8', 'Connection': 'Keep-Alive', 'Content-Security-Policy': "script-src 'self' 'unsafe-inline' 'unsafe-eval'", 'Content-Disposition': 'inline;filename=f.txt', 'Cache-Control': 'no-cache,no-store,must-revalidate', 'Pragma': 'no-cache'}

# %%
r.text
# Out:
# '{"result":"0000","msg":"","lastTime":"20170420210730","dateType":null,"chList":[{"time":"20170420200810","viewCntOTS":654298,"viewCntOTV":1745601,"list":[{"prgm_id":"R019936644","ch_no":"S5","ch_nm":"SBS","disp_ch_nm":"SBS","ch_color":"#26c1ee","view_cnt":29020},{"prgm_id":"R019961829","ch_no":"S13","ch_nm":"채널A","disp_ch_nm":"채널A","ch_color":"#288cbf","view_cnt":9267},{"prgm_id":"R019984664","ch_no":"S15","ch_nm":"JTBC","disp_ch_nm":"JTBC","ch_color":"#bf58b4","view_cnt":42964},{"prgm_id":"R019996306","ch_no":"S7","ch_nm":"KBS2","disp_ch_nm":"KBS2","ch_color":"#9164c3","view_cnt":194953},{"prgm_id":"R019938603","ch_no":"S9","ch_nm":"KBS1","disp_ch_nm":"KBS1","ch_color":"#4a67d3","view_cnt":51268},{"prgm_id":"R020010985","ch_no":"S16","ch_nm":"MBN","disp_ch_nm":"MBN","ch_color":"#ee9700","view_cnt":24160},{"prgm_id":"R019966961","ch_no":"S11","ch_nm":"MBC","disp_ch_nm":"MBC","ch_color":"#cd3d3d","view_cnt":33556},{"prgm_id":"R020006466","ch_no":"S18","ch_nm":"TV조선","disp_ch_nm":"TV조선","ch_color":"#974b39","view_cnt":9674},{"prgm_id":"R020027600","ch_no":"S20","ch_nm":"tvN","disp_ch_nm":"tvN","ch_color":"#ff4747","view_cnt":3357},{"prgm_id":"R019940599","ch_no":"S23","ch_nm":"연합뉴스TV","disp_ch_nm":"연합뉴스TV","ch_color":"#dc6f2d","view_cnt":6727},{"prgm_id":"R020026244","ch_no":"S24","ch_nm":"YTN","disp_ch_nm":"YTN","ch_color":"#17b0ae","view_cnt":9553}]},{"time":"20170420200820","viewCntOTS":654647,"viewCntOTV":1746236,"list":[{"prgm_id":"R019936644","ch_no":"S5","ch_nm":"SBS","disp_ch_nm":"SBS","ch_color":"#26c1ee","view_cnt":28907},{"prgm_id":"R019961829","ch_no":"S13","ch_nm":"채널A","disp_ch_nm":"채널A","ch_color":"#288cbf","view_cnt":9208},{"prgm_id":"R019984664","ch_no":"S15","ch_nm":"JTBC","disp_ch_nm":"JTBC","ch_color":"#bf58b4","view_cnt":43194},{"prgm_id":"R019996306","ch_no":"S7","ch_nm":"KBS2","disp_ch_nm":"KBS2","ch_color":"#9164c3","view_cnt":195216},{"prgm_id":"R019938603","ch_no":"S9","ch_nm":"KBS1","disp_ch_nm":"KBS1","ch_color":"#4a67d3","view_cnt":51235},{"prgm_id":"R020010985","ch_no":"S16","ch_nm":"MBN","disp_ch_nm":"MBN","ch_color":"#ee9700","view_cnt":24258},{"prgm_id":"R019966961","ch_no":"S11","ch_nm":"MBC","disp_ch_nm":"MBC","ch_color":"#cd3d3d","view_cnt":33767},{"prgm_id":"R020006466","ch_no":"S18","ch_nm":"TV조선","disp_ch_nm":"TV조선","ch_color":"#974b39","view_cnt":9616},{"prgm_id":"R020027600","ch_no":"S20","ch_nm":"tvN","disp_ch_nm":"tvN","ch_color":"#ff4747","view_cnt":3344},{"prgm_id":"R019940599","ch_no":"S23","ch_nm":"연합뉴스TV","disp_ch_nm":"연합뉴스TV","ch_color":"#dc6f2d","view_cnt":6715},{"prgm_id":"R020026244","ch_no":"S24","ch_nm":"YTN","disp_ch_nm":"YTN","ch_color":"#17b0ae","view_cnt":9526}]},{"time":"20170420200830","viewCntOTS":655091,"viewCntOTV":1747137,"list":[{"prgm_id":"R019936644","ch_no":"S5","ch_nm":"SBS","disp_ch_nm":"SBS","ch_color":"#26c1ee","view_cnt":28941},{"prgm_id":"R019961829","ch_no":"S13","ch_nm":"채널A","disp_ch_nm":"채널A","ch_color":"#288cbf","view_cnt":9146},{"prgm_id":"R019984664","ch_no":"S15","ch_nm":"JTBC","disp_ch_nm":"JTBC","ch_color":"#bf58b4","view_cnt":43432},{"prgm_id":"R019996306","ch_no":"S7","ch_nm":"KBS2","disp_ch_nm":"KBS2","ch_color":"#9164c3","view_cnt":195364},{"prgm_id":"R019938603","ch_no":"S9","ch_nm":"KBS1","disp_ch_nm":"KBS1","ch_color":"#4a67d3","view_cnt":51165},{"prgm_id":"R020010985","ch_no":"S16","ch_nm":"MBN","disp_ch_nm":"MBN","ch_color":"#ee9700","view_cnt":24308},{"prgm_id":"R019966961","ch_no":"S11","ch_nm":"MBC","disp_ch_nm":"MBC","ch_color":"#cd3d3d","view_cnt":33960},{"prgm_id":"R020006466","ch_no":"S18","ch_nm":"TV조선","disp_ch_nm":"TV조선","ch_color":"#974b39","view_cnt":9572},{"prgm_id":"R020027600","ch_no":"S20","ch_nm":"tvN","disp_ch_nm":"tvN","ch_color":"#ff4747","view_cnt":3346},{"prgm_id":"R019940599","ch_no":"S23","ch_nm":"연합뉴스TV","disp_ch_nm":"연합뉴스TV","ch_color":"#dc6f2d","view_cnt":6700},{"prgm_id":"R020026244","ch_no":"S24","ch_nm":"YTN","disp_ch_nm":"YTN","ch_color":"#17b0ae","view_cnt":9525}]},{"time":"20170420200840","viewCntOTS":65 ...

# %%
data = json.loads(r.text)

# %%
len(data['chList'])
# Out:
# 357

# %%
temp = []
for item in data['chList']:
    row = []    
    for temprow in item['list']:
        listitem = {}
        listitem['time'] = item['time']
        listitem['prgm_id'] = temprow['prgm_id']
        listitem['ch_color'] = temprow['ch_color']
        listitem['ch_no'] = temprow['ch_no']
        listitem['ch_nm'] = temprow['ch_nm']
        listitem['disp_ch_nm'] = temprow['disp_ch_nm']
        listitem['view_cnt'] = temprow['view_cnt']
        print(listitem)
        #row.append(listitem)
        temp.append(listitem)

temp
# Out:
# {'disp_ch_nm': 'SBS', 'prgm_id': 'R019936644', 'ch_nm': 'SBS', 'time': '20170420
# {'disp_ch_nm': 'tvN', 'prgm_id': 'R020027600', 'ch_nm': 'tvN', 'time': '20170420201250', 'ch_no': 'S20', 'view_cnt': 3115, 'ch_color': '#ff4747'}
# {'disp_ch_nm': '연합뉴스TV', 'prgm_id': 'R019940599', 'ch_nm': '연합뉴스TV', 'time': '20170420201250', 'ch_no': 'S23', 'view_cnt': 7358, 'ch_color': '#dc6f2d'}
# {'disp_ch_nm': 'YTN', 'prgm_id': 'R020026244', 'ch_nm': 'YTN', 'time': '20170420201250', 'ch_no': 'S24', 'view_cnt': 6498, 'ch_color': '#17b0ae'}
# {'disp_ch_nm': 'SBS', 'prgm_id': 'R019936644', 'ch_nm': 'SBS', 'time': '20170420201300', 'ch_no': 'S5', 'view_cnt': 31788, 'ch_color': '#26c1ee'}
# {'disp_ch_nm': '채널A', 'prgm_id': 'R019961829', 'ch_nm': '채널A', 'time': '20170420201300', 'ch_no': 'S13', 'view_cnt': 6915, 'ch_color': '#288cbf'}
# {'disp_ch_nm': 'JTBC', 'prgm_id': 'R019984664', 'ch_nm': 'JTBC', 'time': '20170420201300', 'ch_no': 'S15', 'view_cnt': 49708, 'ch_color': '#bf58b4'}
# {'disp_ch_nm': 'KBS2', 'prgm_id': 'R019996306', 'ch_nm': 'KBS2', 'time': '20170420201300', 'ch_no': 'S7', 'view_cnt': 198849, 'ch_color': '#9164c3'}
# {'disp_ch_nm': 'KBS1', 'prgm_id': 'R019938603', 'ch_nm': 'KBS1', 'time': '20170420201300', 'ch_no': 'S9', 'view_cnt': 51802, 'ch_color': '#4a67d3'}
# {'disp_ch_nm': 'MBN', 'prgm_id': 'R020010985', 'ch_nm': 'MBN', 'time': '20170420201300', 'ch_no': 'S16', 'view_cnt': 20405, 'ch_color': '#ee9700'}
# ...
#   'ch_nm': 'YTN',
#   'ch_no': 'S24',
#   'disp_ch_nm': 'YTN',
#   'prgm_id': 'R020026245',
#   'time': '20170420202140',
#   'view_cnt': 6469},
#  {'ch_color': '#26c1ee',
#   'ch_nm': 'SBS',
#   'ch_no': 'S5',
#   'disp_ch_nm': 'SBS',
#   'prgm_id': 'R019936644',
#   'time': '20170420202150',
#   'view_cnt': 34386},
#  {'ch_color': '#288cbf',
#   'ch_nm': '채널A',
#   'ch_no': 'S13',
#   'disp_ch_nm': '채널A',
#   'prgm_id': 'R020004316',
#   'time': '20170420202150',
#   'view_cnt': 4969},
#  {'ch_color': '#bf58b4',
#   'ch_nm': 'JTBC',
#   'ch_no': 'S15',
#   'disp_ch_nm': 'JTBC',
#   'prgm_id': 'R019984664',
#   'time': '20170420202150',
#   'view_cnt': 54686},
#  {'ch_color': '#9164c3',
#   'ch_nm': 'KBS2',
#   'ch_no': 'S7',
#   'disp_ch_nm': 'KBS2',
#   'prgm_id': 'R019996306',
#   'time': '20170420202150',
#   'view_cnt': 200629},
#  {'ch_color': '#4a67d3',
#   'ch_nm': 'KBS1',
#   'ch_no': 'S9',
#   'disp_ch_nm': 'KBS1',
#   'prgm_id': 'R019938603',
#   'time': '20170420202150',
#   'view_cnt': 51377},
#  {'ch_color': '#ee9700',
#   'ch_nm': 'MBN',
#   'ch_no': 'S16',
#   'disp_ch_nm': 'MBN',
#   'prgm_id': 'R020010985',
#   'time': '20170420202150',
#   'view_cnt': 20944},
#  {'ch_color': '#cd3d3d',
#   'ch_nm': 'MBC',
#   'ch_no': 'S11',
#   'disp_ch_nm': 'MBC',
#   'prgm_id': 'R019966961',
#   'time': '20170420202150',
#   'view_cnt': 40007},
#  {'ch_color': '#974b39',
#   'ch_nm': 'TV조선',
#   'ch_no': 'S18',
#   'disp_ch_nm': 'TV조선',
#   'prgm_id': 'R020006466',
#   'time': '20170420202150',
#   'view_cnt': 6828},
#  {'ch_color': '#ff4747',
#   'ch_nm': 'tvN',
#   'ch_no': 'S20',
#   'disp_ch_nm': 'tvN',
#   'prgm_id': 'R020027601',
#   'time': '20170420202150',
#   'view_cnt': 3794},
#  {'ch_color': '#dc6f2d',
#   'ch_nm': '연합뉴스TV',
#   'ch_no': 'S23',
#   'disp_ch_nm': '연합뉴스TV',
#   'prgm_id': 'R019940599',
#   'time': '20170420202150',
#   'view_cnt': 7034},
#  {'ch_color': '#17b0ae',
#   'ch_nm': 'YTN',
#   'ch_no': 'S24',
#   'disp_ch_nm': 'YTN',
#   'prgm_id': 'R020026245',
#   'time': '20170420202150',
#   'view_cnt': 6470},
#  {'ch_color': '#26c1ee',
#   'ch_nm': 'SBS',
#   'ch_no': 'S5',
#   'disp_ch_nm': 'SBS',
#   'prgm_id': 'R019936644',
#   'time': '20170420202200',
#   'view_cnt': 34674},
#  {'ch_color': '#288cbf',
#   'ch_nm': '채널A',
#   'ch_no': 'S13',
#   'disp_ch_nm': '채널A',
#   'prgm_id': 'R020004316',
#   'time': '20170420202200',
#   'view_cnt': 4948},
#  {'ch_color': '#bf58b4',
#   'ch_nm': 'JTBC',
#   'ch_no': 'S15',
#   'disp_ch_nm': 'JTBC',
#   'prgm_id': 'R019984664',
#   'time': '20170420202200',
#   'view_cnt': 54899},
#  {'ch_color': '#9164c3',
#   'ch_nm': 'KBS2',
#   'ch_no': 'S7',
#   'disp_ch_nm': 'KBS2',
#   'prgm_id': 'R019996306',
#   'time': '20170420202200',
#   'view_cnt': 200725},
#  {'ch_color': '#4a67d3',
#   'ch_nm': 'KBS1',
#   'ch_no': 'S9',
#   'disp_ch_nm': 'KBS1',
#   'prgm_id': 'R019938603',
#   'time': '20170420202200',
#   'view_cnt': 50076},
#  {'ch_color': '#ee9700',
#   'ch_nm': 'MBN',
#   'ch_no': 'S16',
#   'disp_ch_nm': 'MBN',
#   'prgm_id': 'R020010985',
#   'time': '20170420202200',
#   'view_cnt': 20882},
#  {'ch_color': '#cd3d3d',
#   'ch_nm': 'MBC',
#   'ch_no': 'S11',
#   'disp_ch_nm': 'MBC',
#   'prgm_id': 'R019966961',
#   'time': '20170420202200',
#   'view_cnt': 40430},
#  {'ch_color': '#974b39',
#   'ch_nm': 'TV조선',
#   'ch_no': 'S18',
#   'disp_ch_nm': 'TV조선',
#   'prgm_id': 'R020006466',
#   'time': '20170420202200',
#   'view_cnt': 6869},
#  {'ch_color': '#ff4747',
#   'ch_nm': 'tvN',
#   'ch_no': 'S20',
#   'disp_ch_nm': 'tvN',
#   'prgm_id': 'R020027601',
#   'time': '20170420202200',
#   'view_cnt': 3875},
#  {'ch_color': '#dc6f2d',
#   'ch_nm': '연합뉴스TV',
#   'ch_no': 'S23',
#   'disp_ch_nm': '연합뉴스TV',
#   'prgm_id': 'R019940599',
#   'time': '20170420202200',
#   'view_cnt': 7037},
#  {'ch_color': '#17b0ae',
#   'ch_nm': 'YTN',
#   'ch_no': 'S24',
#   'disp_ch_nm': 'YTN',
#   'prgm_id': 'R020026245',
#   'time': '20170420202200',
#   'view_cnt': 6423},
#  {'ch_color': '#26c1ee',
#   'ch_nm': 'SBS',
#   'ch_no': 'S5',
#   'disp_ch_nm': 'SBS',
#   'prgm_id': 'R019936644',
#   'time': '20170420202210',
#   'view_cnt': 34920},
#  {'ch_color': '#288cbf',
#   'ch_nm': '채널A',
#   'ch_no': 'S13',
#   'disp_ch_nm': '채널A',
#   'prgm_id': 'R020004316',
#   'time': '20170420202210',
#   'view_cnt': 4925},
#  {'ch_color': '#bf58b4',
#   'ch_nm': 'JTBC',
#   'ch_no': 'S15',
#   'disp_ch_nm': 'JTBC',
#   'prgm_id': 'R019984664',
#   'time': '20170420202210',
#   'view_cnt': 54993},
#  {'ch_color': '#9164c3',
#   'ch_nm': 'KBS2',
#   'ch_no': 'S7',
#   'disp_ch_nm': 'KBS2',
#   'prgm_id': 'R019996306',
#   'time': '20170420202210',
#   'view_cnt': 200682},
#  {'ch_color': '#4a67d3',
#   'ch_nm': 'KBS1',
#   'ch_no': 'S9',
#   'disp_ch_nm': 'KBS1',
#   'prgm_id': 'R019938603',
#   'time': '20170420202210',
#   'view_cnt': 49380},
#  {'ch_color': '#ee9700',
#   'ch_nm': 'MBN',
#   'ch_no': 'S16',
#   'disp_ch_nm': 'MBN',
#   'prgm_id': 'R020010985',
#   'time': '20170420202210',
#   'view_cnt': 20844},
#  {'ch_color': '#cd3d3d',
#   'ch_nm': 'MBC',
#   'ch_no': 'S11',
#   'disp_ch_nm': 'MBC',
#   'prgm_id': 'R019966961',
#   'time': '20170420202210',
#   'view_cnt': 40682},
#  {'ch_color': '#974b39',
#   'ch_nm': 'TV조선',
#   'ch_no': 'S18',
#   'disp_ch_nm': 'TV조선',
#   'prgm_id': 'R020006466',
#   'time': '20170420202210',
#   'view_cnt': 6889},
#  {'ch_color': '#ff4747',
#   'ch_nm': 'tvN',
#   'ch_no': 'S20',
#   'disp_ch_nm': 'tvN',
#   'prgm_id': 'R020027601',
#   'time': '20170420

#  {'ch_color': '#9164c3',
#   'ch_nm': 'KBS2',
#   'ch_no': 'S7',
#   'disp_ch_nm': 'KBS2',
#   'prgm_id': 'R019996306',
#   'time': '20170420202230',
#   'view_cnt': 200410},
#  {'ch_color': '#4a67d3',
#   'ch_nm': 'KBS1',
#   'ch_no': 'S9',
#   'disp_ch_nm': 'KBS1',
#   'prgm_id': 'R019938603',
#   'time': '20170420202230',
#   'view_cnt': 48979},
#  {'ch_color': '#ee9700',
#   'ch_nm': 'MBN',
#   'ch_no': 'S16',
#   'disp_ch_nm': 'MBN',
#   'prgm_id': 'R020010985',
#   'time': '20170420202230',
#   'view_cnt': 20573},
#  {'ch_color': '#cd3d3d',
#   'ch_nm': 'MBC',
#   'ch_no': 'S11',
#   'disp_ch_nm': 'MBC',
#   'prgm_id': 'R019966961',
#   'time': '20170420202230',
#   'view_cnt': 40843},
#  {'ch_color': '#974b39',
#   'ch_nm': 'TV조선',
#   'ch_no': 'S18',
#   'disp_ch_nm': 'TV조선',
#   'prgm_id': 'R020006466',
#   'time': '20170420202230',
#   'view_cnt': 7024},
#  {'ch_color': '#ff4747',
#   'ch_nm': 'tvN',
#   'ch_no': 'S20',
#   'disp_ch_nm': 'tvN',
#   'prgm_id': 'R020027601',
#   'time': '20170420202230',
#   'view_cnt': 4163},
#  {'ch_color': '#dc6f2d',
#   'ch_nm': '연합뉴스TV',
#   'ch_no': 'S23',
#   'disp_ch_nm': '연합뉴스TV',
#   'prgm_id': 'R019940599',
#   'time': '20170420202230',
#   'view_cnt': 6996},
#  {'ch_color': '#17b0ae',
#   'ch_nm': 'YTN',
#   'ch_no': 'S24',
#   'disp_ch_nm': 'YTN',
#   'prgm_id': 'R020026245',
#   'time': '20170420202230',
#   'view_cnt': 6489},
#  {'ch_color': '#26c1ee',
#   'ch_nm': 'SBS',
#   'ch_no': 'S5',
#   'disp_ch_nm': 'SBS',
#   'prgm_id': 'R019936644',
#   'time': '20170420202240',
#   'view_cnt': 35614},
#  {'ch_color': '#288cbf',
#   'ch_nm': '채널A',
#   'ch_no': 'S13',
#   'disp_ch_nm': '채널A',
#   'prgm_id': 'R020004316',
#   'time': '20170420202240',
#   'view_cnt': 4838},
#  {'ch_color': '#bf58b4',
#   'ch_nm': 'JTBC',
#   'ch_no': 'S15',
#   'disp_ch_nm': 'JTBC',
#   'prgm_id': 'R019984664',
#   'time': '20170420202240',
#   'view_cnt': 55689},
#  {'ch_color': '#9164c3',
#   'ch_nm': 'KBS2',
#   'ch_no': 'S7',
#   'disp_ch_nm': 'KBS2',
#   'prgm_id': 'R019996306',
#   'time': '20170420202240',
#   'view_cnt': 200325},
#  {'ch_color': '#4a67d3',
#   'ch_nm': 'KBS1',
#   'ch_no': 'S9',
#   'disp_ch_nm': 'KBS1',
#   'prgm_id': 'R019938603',
#   'time': '20170420202240',
#   'view_cnt': 49174},
#  {'ch_color': '#ee9700',
#   'ch_nm': 'MBN',
#   'ch_no': 'S16',
#   'disp_ch_nm': 'MBN',
#   'prgm_id': 'R020010985',
#   'time': '20170420202240',
#   'view_cnt': 20411},
#  {'ch_color': '#cd3d3d',
#   'ch_nm': 'MBC',
#   'ch_no': 'S11',
#   'disp_ch_nm': 'MBC',
#   'prgm_id': 'R019966961',
#   'time': '20170420202240',
#   'view_cnt': 40793},
#  {'ch_color': '#974b39',
#   'ch_nm': 'TV조선',
#   'ch_no': 'S18',
#   'disp_ch_nm': 'TV조선',
#   'prgm_id': 'R020006466',
#   'time': '20170420202240',
#   'view_cnt': 7058},
#  {'ch_color': '#ff4747',
#   'ch_nm': 'tvN',
#   'ch_no': 'S20',
#   'disp_ch_nm': 'tvN',
#   'prgm_id': 'R020027601',
#   'time': '20170420202240',
#   'view_cnt': 4245},
#  {'ch_color': '#dc6f2d',
#   'ch_nm': '연합뉴스TV',
#   'ch_no': 'S23',
#   'disp_ch_nm': '연합뉴스TV',
#   'prgm_id': 'R019940599',
#   'time': '20170420202240',
#   'view_cnt': 6974},
#  {'ch_color': '#17b0ae',
#   'ch_nm': 'YTN',
#   'ch_no': 'S24',
#   'disp_ch_nm': 'YTN',
#   'prgm_id': 'R020026245',
#   'time': '20170420202240',
#   'view_cnt': 6497},
#  {'ch_color': '#26c1ee',
#   'ch_nm': 'SBS',
#   'ch_no': 'S5',
#   'disp_ch_nm': 'SBS',
#   'prgm_id': 'R019936644',
#   'time': '20170420202250',
#   'view_cnt': 35773},
#  {'ch_color': '#288cbf',
#   'ch_nm': '채널A',
#   'ch_no': 'S13',
#   'disp_ch_nm': '채널A',
#   'prgm_id': 'R020004316',
#   'time': '20170420202250',
#   'view_cnt': 4814},
#  {'ch_color': '#bf58b4',
#   'ch_nm': 'JTBC',
#   'ch_no': 'S15',
#   'disp_ch_nm': 'JTBC',
#   'prgm_id': 'R019984664',
#   'time': '20170420202250',
#   'view_cnt': 55890},
#  {'ch_color': '#9164c3',
#   'ch_nm': 'KBS2',
#   'ch_no': 'S7',
#   'disp_ch_nm': 'KBS2',
#   'prgm_id': 'R019996306',
#   'time': '20170420202250',
#   'view_cnt': 200631},
#  {'ch_color': '#4a67d3',
#   'ch_nm': 'KBS1',
#   'ch_no': 'S9',
#   'disp_ch_nm': 'KBS1',
#   'prgm_id': 'R019938603',
#   'time': '20170420202250',
#   'view_cnt': 49548},
#  {'ch_color': '#ee9700',
#   'ch_nm': 'MBN',
#   'ch_no': 'S16',
#   'disp_ch_nm': 'MBN',
#   'prgm_id': 'R020010985',
#   'time': '20170420202250',
#   'view_cnt': 20164},
#  {'ch_color': '#cd3d3d',
#   'ch_nm': 'MBC',
#   'ch_no': 'S11',
#   'disp_ch_nm': 'MBC',
#   'prgm_id': 'R019966961',
#   'time': '20170420202250',
#   'view_cnt': 40905},
#  {'ch_color': '#974b39',
#   'ch_nm': 'TV조선',
#   'ch_no': 'S18',
#   'disp_ch_nm': 'TV조선',
#   'prgm_id': 'R020006466',
#   'time': '20170420202250',
#   'view_cnt': 7090},
#  {'ch_color': '#ff4747',
#   'ch_nm': 'tvN',
#   'ch_no': 'S20',
#   'disp_ch_nm': 'tvN',
#   'prgm_id': 'R020027601',
#   'time': '20170420202250',
#   'view_cnt': 4336},
#  {'ch_color': '#dc6f2d',
#   'ch_nm': '연합뉴스TV',
#   'ch_no': 'S23',
#   'disp_ch_nm': '연합뉴스TV',
#   'prgm_id': 'R019940599',
#   'time': '20170420202250',
#   'view_cnt': 6944},
#  {'ch_color': '#17b0ae',
#   'ch_nm': 'YTN',
#   'ch_no': 'S24',
#   'disp_ch_nm': 'YTN',
#   'prgm_id': 'R020026245',
#   'time': '20170420202250',
#   'view_cnt': 6471},
#  {'ch_color': '#26c1ee',
#   'ch_nm': 'SBS',
#   'ch_no': 'S5',
#   'disp_ch_nm': 'SBS',
#   'prgm_id': 'R019936644',
#   'time': '20170420202300',
#   'view_cnt': 35934},
#  {'ch_color': '#288cbf',
#   'ch_nm': '채널A',
#   'ch_no': 'S13',
#   'disp_ch_nm': '채널A',
#   'prgm_id': 'R020004316',
#   'time': '20170420202300',
#   'view_cnt': 4787},
#  {'ch_color': '#bf58b4',
#   'ch_nm': 'JTBC',
#   'ch_no': 'S15',
#   'disp_ch_nm': 'JTBC',
#   'prgm_id': 'R019984664',
#   'time': '20170420202300',
#   'view_cnt': 56061},
#  {'ch_color': '#9164c3',
#   'ch_nm': 'KBS2',
#   'ch_no': 'S7',
#   'disp_ch_nm': 'KBS2',
#   'prgm_id': 'R019996306',
#   'time': '20170420202300',
#   'view_cnt': 200759},
#  {'ch_color': '#4a67d3',
#   'ch_nm': 'KBS1',
#   'ch_no': 'S9',
#   'disp_ch_nm': 'KBS1',
#   'prgm_id': 'R019938603',
#   'time': '20170420202300',
#   'view_cnt': 50040},
#  {'ch_color': '#ee9700',
#   'ch_nm': 'MBN',
#   'ch_no': 'S16',
#   'disp_ch_nm': 'MBN',
#   'prgm_id': 'R020010985',
#   'time': '20170420202300',
#   'view_cnt': 19953},
#  {'ch_color': '#cd3d3d',
#   'ch_nm': 'MBC',
#   'ch_no': 'S11',
#   'disp_ch_nm': 'MBC',
#   'prgm_id': 'R019966961',
#   'time': '20170420202300',
#   'view_cnt': 41066},
#  {'ch_color': '#974b39',
#   'ch_nm': 'TV조선',
#   'ch_no': 'S18',
#   'disp_ch_nm': 'TV조선',
#   'prgm_id': 'R020006466',
#   'time': '20170420202300',
#   'view_cnt': 7091},
#  {'ch_color': '#ff4747',
#   'ch_nm': 'tvN',
#   'ch_no': 'S20',
#   'disp_ch_nm': 'tvN',
#   'prgm_id': 'R020027601',
#   'time': '20170420202300',
#   'view_cnt': 4429},
#  {'ch_color': '#dc6f2d',
#   'ch_nm': '연합뉴스TV',
#   'ch_no': 'S23',
#   'disp_ch_nm': '연합뉴스TV',
#   'prgm_id': 'R019940599',
#   'time': '20170420202300',
#   'view_cnt': 6918},
#  {'ch_color': '#17b0ae',
#   'ch_nm': 'YTN',
#   'ch_no': 'S24',
#   'disp_ch_nm': 'YTN',
#   'prgm_id': 'R020026245',
#   'time': '20170420202300',
#   'view_cnt': 6489},
#  {'ch_color': '#26c1ee',
#   'ch_nm': 'SBS',
#   'ch_no': 'S5',
#   'disp_ch_nm': 'SBS',
#   'prgm_id': 'R019936644',
#   'time': '20170420202310',
#   'view_cnt': 36121},
#  {'ch_color': '#288cbf',
#   'ch_nm': '채널A',
#   'ch_no': 'S13',
#   'disp_ch_nm': '채널A',
#   'prgm_id': 'R020004316',
#   'time': '20170420202310',
#   'view_cnt': 4750},
#  {'ch_color': '#bf58b4',
#   'ch_nm': 'JTBC',
#   'ch_no': 'S15',
#   'disp_ch_nm': 'JTBC',
#   'prgm_id': 'R019984664',
#   'time': '20170420202310',
#   'view_cnt': 56090},
#  {'ch_color': '#9164c3',
#   'ch_nm': 'KBS2',
#   'ch_no': 'S7',
#   'disp_ch_nm': 'KBS2',
#   'prgm_id': 'R019996306',
#   'time': '20170420202310',
#   'view_cnt': 199995},
#  {'ch_color': '#4a67d3',
#   'ch_nm': 'KBS1',
#   'ch_no': 'S9',
#   'disp_ch_nm': 'KBS1',
#   'prgm_id': 'R019938603',
#   'time': '20170420202310',
#   'view_cnt': 50969},
#  {'ch_color': '#ee9700',
#   'ch_nm': 'MBN',
#   'ch_no': 'S16',
#   'disp_ch_nm': 'MBN',
#   'prgm_id': 'R020010985',
#   'time': '20170420202310',
#   'view_cnt': 19857},
#  {'ch_color': '#cd3d3d',
#   'ch_nm': 'MBC',
#   'ch_no': 'S11',
#   'disp_ch_nm': 'MBC',
#   'prgm_id': 'R019966961',
#   'time': '20170420202310',
#   'view_cnt': 41251},
#  {'ch_color': '#974b39',
#   'ch_nm': 'TV조선',
#   'ch_no': 'S18',
#   'disp_ch_nm': 'TV조선',
#   'prgm_id': 'R020006466',
#   'time': '20170420202310',
#   'view_cnt': 7049},
#  {'ch_color': '#ff4747',
#   'ch_nm': 'tvN',
#   'ch_no': 'S20',
#   'disp_ch_nm': 'tvN',
#   'prgm_id': 'R020027601',
#   'time': '20170420202310',
#   'view_cnt': 4512},
#  {'ch_color': '#dc6f2d',
#   'ch_nm': '연합뉴스TV',
#   'ch_no': 'S23',
#   'disp_ch_nm': '연합뉴스TV',
#   'prgm_id': 'R019940599',
#   'time': '20170420202310',
#   'view_cnt': 6883},
#  ...]

# %%
df_mbs = pd.DataFrame(temp)
df_mbs
# Out:
#      ch_color   ch_nm ch_no disp_ch_nm     prgm_id            time  view_cnt
# 0     #26c1ee     SBS    S5        SBS  R019936644  20170420200810     29020
# 1     #288cbf     채널A   S13        채널A  R019961829  20170420200810      9267
# 2     #bf58b4    JTBC   S15       JTBC  R019984664  20170420200810     42964
# 3     #9164c3    KBS2    S7       KBS2  R019996306  20170420200810    194953
# 4     #4a67d3    KBS1    S9       KBS1  R019938603  20170420200810     51268
# 5     #ee9700     MBN   S16        MBN  R020010985  20170420200810     24160
# 6     #cd3d3d     MBC   S11        MBC  R019966961  20170420200810     33556
# 7     #974b39    TV조선   S18       TV조선  R020006466  20170420200810      9674
# 8     #ff4747     tvN   S20        tvN  R020027600  20170420200810      3357
# 9     #dc6f2d  연합뉴스TV   S23     연합뉴스TV  R019940599  20170420200810      6727
# 10    #17b0ae     YTN   S24        YTN  R020026244  20170420200810      9553
# 11    #26c1ee     SBS    S5        SBS  R019936644  20170420200820     28907
# 12    #288cbf     채널A   S13        채널A  R019961829  20170420200820      9208
# 13    #bf58b4    JTBC   S15       JTBC  R019984664  20170420200820     43194
# 14    #9164c3    KBS2    S7       KBS2  R019996306  20170420200820    195216
# 15    #4a67d3    KBS1    S9       KBS1  R019938603  20170420200820     51235
# 16    #ee9700     MBN   S16        MBN  R020010985  20170420200820     24258
# 17    #cd3d3d     MBC   S11        MBC  R019966961  20170420200820     33767
# 18    #974b39    TV조선   S18       TV조선  R020006466  20170420200820      9616
# 19    #ff4747     tvN   S20        tvN  R020027600  20170420200820      3344
# 20    #dc6f2d  연합뉴스TV   S23     연합뉴스TV  R019940599  20170420200820      6715
# 21    #17b0ae     YTN   S24        YTN  R020026244  20170420200820      9526
# 22    #26c1ee     SBS    S5        SBS  R019936644  20170420200830     28941
# 23    #288cbf     채널A   S13        채널A  R019961829  20170420200830      9146
# 24    #bf58b4    JTBC   S15       JTBC  R019984664  20170420200830     43432
# 25    #9164c3    KBS2    S7       KBS2  R019996306  20170420200830    195364
# 26    #4a67d3    KBS1    S9       KBS1  R019938603  20170420200830     51165
# 27    #ee9700     MBN   S16        MBN  R020010985  20170420200830     24308
# 28    #cd3d3d     MBC   S11        MBC  R019966961  20170420200830     33960
# 29    #974b39    TV조선   S18       TV조선  R020006466  20170420200830      9572
# ...       ...     ...   ...        ...         ...             ...       ...
# 3897  #9164c3    KBS2    S7       KBS2  R019996308  20170420210710     29084
# 3898  #4a67d3    KBS1    S9       KBS1  R019938605  20170420210710    137930
# 3899  #ee9700     MBN   S16        MBN  R020010986  20170420210710     13765
# 3900  #cd3d3d     MBC   S11        MBC  R019986803  20170420210710     81678
# 3901  #974b39    TV조선   S18       TV조선  R020020415  20170420210710     10595
# 3902  #ff4747     tvN   S20        tvN  R020027601  20170420210710     16176
# 3903  #dc6f2d  연합뉴스TV   S23     연합뉴스TV  R019940600  20170420210710      8411
# 3904  #17b0ae     YTN   S24        YTN  R020026246  20170420210710      6685
# 3905  #26c1ee     SBS    S5        SBS  R019936645  20170420210720     61586
# 3906  #288cbf     채널A   S13        채널A  R020004316  20170420210720     10136
# 3907  #bf58b4    JTBC   S15       JTBC  R019984664  20170420210720     56753
# 3908  #9164c3    KBS2    S7       KBS2  R019996308  20170420210720     29189
# 3909  #4a67d3    KBS1    S9       KBS1  R019938605  20170420210720    137806
# 3910  #ee9700     MBN   S16        MBN  R020010986  20170420210720     13713
# 3911  #cd3d3d     MBC   S11        MBC  R019986803  20170420210720     81745
# 3912  #974b39    TV조선   S18       TV조선  R020020415  20170420210720     10611
# 3913  #ff4747     tvN   S20        tvN  R020027601  20170420210720     16204
# 3914  #dc6f2d  연합뉴스TV   S23     연합뉴스TV  R019940600  20170420210720      8430
# 3915  #17b0ae     YTN   S24        YTN  R020026246  20170420210720      6660
# 3916  #26c1ee     SBS    S5        SBS  R019936645  20170420210730     61717
# 3917  #288cbf     채널A   S13        채널A  R020004316  20170420210730     10151
# 3918  #bf58b4    JTBC   S15       JTBC  R019984664  20170420210730     56707
# 3919  #9164c3    KBS2    S7       KBS2  R019996308  20170420210730     29281
# 3920  #4a67d3    KBS1    S9       KBS1  R019938605  20170420210730    137404
# 3921  #ee9700     MBN   S16        MBN  R020010986  20170420210730     13714
# 3922  #cd3d3d     MBC   S11        MBC  R019986803  20170420210730     81820
# 3923  #974b39    TV조선   S18       TV조선  R020020415  20170420210730     10597
# 3924  #ff4747     tvN   S20        tvN  R020027601  20170420210730     16239
# 3925  #dc6f2d  연합뉴스TV   S23     연합뉴스TV  R019940600  20170420210730      8442
# 3926  #17b0ae     YTN   S24        YTN  R020026246  20170420210730      6648
#
# [3927 rows x 7 columns]

# %% [markdown]
# # CSV 출력하기

# %%
df_mbs.to_excel('skylife_range_interest_ch.xlsx', sheet_name='interest_ch')

# %%
df_mbs.to_csv('skylife_range_interest_ch.csv')

# %% [markdown]
# # 현재 시간 구하기

# %%
import datetime

# %%
today = datetime.datetime.today() 
today.strftime('%Y%m%d%H%M%S')
# Out:
# '20170405144321'
